# %% [markdown]
# ## GRQs: Regular Expressions
# ***due Tuesday 07/14 at 11:30am (EST)***
#
# Answer each of the following questions with either the requested code or a multi-sentence written response. This assignment will be scored on completion.

# %% [markdown]
# ---
#
# **Name:** *[Your name here]*
# **ID:** *[Your netID here]*
#
# ---

# %% [markdown]
# ### Question 1
# *Adapted from Exercise 8.12.1 in "Think Python" by Allen B. Downey and Runestone Academy's Regular Expression Practice Problems*
#
# There's a lot that regular expressions can do that wasn't covered in this reading. To probe a little more into this topic, ask the AI chatbot of your choice "What are the most common special characters used in Python regular expressions?". Then, using the information it provided, try to write regular expressions that will match the following sequences *without the chatbot's help*.

# %% [markdown]
# ---
#
# *[Name your chatbot and paste all interactions here – prompts and responses]*
#
# ---

# %% [markdown]
# **1.1:** Match both `cat` and `cats`.

# %% [markdown]
# ---
#
# *[Write your regex here]*
#
# ---

# %% [markdown]
# **1.2:** Match both `gray` and `grey`.

# %% [markdown]
# ---
#
# *[Write your regex here]*
#
# ---

# %% [markdown]
# **1.3:** Match `br` followed by any single character except for a new line and then a `3`.

# %% [markdown]
# ---
#
# *[Write your regex here]*
#
# ---

# %% [markdown]
# **1.4:** A word that starts with an uppercase letter followed by at least one lowercase letter, like “Apple”, “Banana”, or “Carrot”.

# %% [markdown]
# ---
#
# *[Write your regex here]*
#
# ---

# %% [markdown]
# ### Question 2
#
# The examples above are relatively simple. We can imagine more complicated, and hopefully more useful, regular expressions that can match specific strings like emails or dates. Brainstorm 2-3 other kinds of strings you might want to match with regular expressions – the weirder the better, as long as you actually think they're useful!

# %% [markdown]
# ---
#
# *[Write your regular expression here]*
#
# ---

# %% [markdown]
# ### Question 3
# *Adapted from Exercise 8.12.1 in "Think Python" by Allen B. Downey*
#
# Writing more complicated regular expressions, like the kind you may have brainstormed above, can be challenging. Regexes can be surprisingly complicated to write and rely on syntax that can be unintuitive! Most programmers who you meet won't be able to write complex regexes off the top of their head. Luckily, this is one place that AI can be super valuable!
#
# Ask the AI chatbot of your choice to provide you with the regex that matches each of the following sequences. Ask enough follow-up questions so that you understand each element of the provided regex and provide a 1-2 sentence description of how it works.

# %% [markdown]
# ---
#
# *[Name your chatbot and paste all interactions here – prompts and responses]*
#
# ---

# %% [markdown]
# **3.1:** Match a street address with a number and a street name, followed by `ST` or `AVE`.

# %% [markdown]
# ---
#
# *[Write your regex here]*
#
# ---

# %% [markdown]
# ---
#
# *[Explain your regex here]*
#
# ---

# %% [markdown]
# **3.2:** Match a full name with any common title like `Mr` or `Mrs` followed by any number of names beginning with capital letters, possibly with hyphens between some names.

# %% [markdown]
# ---
#
# *[Write your regex here]*
#
# ---

# %% [markdown]
# ---
#
# *[Explain your regex here]*
#
# ---

# %% [markdown]
# **3.3:** Match common http:// and https:// web URLs.

# %% [markdown]
# ---
#
# *[Write your regex here]*
#
# ---

# %% [markdown]
# ---
#
# *[Explain your regex here]*
#
# ---

# %% [markdown]
# ### Question 4
#
# There are some sequences that you *can't* match using regular expressions. To truly understand why in depth requires a bit of computer science theory that is outside the scope of this class. However, it's interesting (and useful) to understand the basics!
#
# Do some research on the restrictions of regular expressions. You can use any outside source, including Google, an AI chatbot, or a knowledgable friend. Cite all of your sources (including prompts and responses, if using a chatbot) and then synthesize what you've learned into a 3-5 sentence explanation.

# %% [markdown]
# ---
#
# *[List the sources you used here, including all prompts and responses if a chatbot was used]*
#
# ---

# %% [markdown]
# ---
#
# *[Write your explanation here]*
#
# ---
