# %% [markdown]
# ## Lab 15: Multidimensional Data with NumPy
#
# ***due Thursday 07/23 at 11:30am (EST)***
#
# After finishing this lab, submit the `lab-15.ipynb` file on Canvas.

# %% [markdown]
# ---
#
# **Name:** *[Your name here]*
# **ID:** *[Your netID here]*
#
# ---

# %% [markdown]
# ### In the Field
#
# For this lab, we'll be replicating what it might be like to do analysis with NumPy of real-world scientific data. In the code cell below, I've loaded a NumPy array that contains blood test data from patients at various stages of Hepatitis-C. The data is available [here](https://archive.ics.uci.edu/dataset/571/hcv+data) as part of the UCI Machine Learning Repository. It was published alongside the paper ["Using machine learning techniques to generate laboratory diagnostic pathways—a case study"](https://www.semanticscholar.org/paper/Using-machine-learning-techniques-to-generate-case-Hoffmann-Bietenbeck/26d42f15a80f3629f5de44262891dd25979e4be3) by Hoffmann et al. (2018).
#
# As always, it's important to be thoughtful while using real-world datasets, especially those with data that represent humans. Although we'll be using this dataset to learn more about using NumPy, it's important to remember that it represents real people.
#
# The dataset contains 13 values. The first is an integer label representing the Hepatitis-C status of the individual: 0 (healthy blood donor), 1 (Hepatitis), 2 (Fibrosis), or 3 (Cirrhosis). Some of the blood donors' health status is unknown – for the purposes of this lab, these are grouped in with the other blood donors. The second value in the data set is age (in years) and the third labels binary sex, where 0 is male and 1 is female. The remaining values represent different blood test values: ALB (albumin), ALP (alkaline phosphatase), ALT (alanine transaminase), AST (aspartate aminotransferase), BIL (bilirubin), CHE (cholinesterase), CHOL (cholesterol), CREA (creatinine), GGT (gamma-glutamyl transferase), and PROT (protein).
#
# The code cell below loads the relevant dataset as a numpy array in the variable `hcv_data`.

# %%
import numpy as np

with open("lab-files/hcv_data.npy", "rb") as f:
    hcv_data = np.load(f)

# %% [markdown]
# #### Part 1
#
# Determine the number of patients represented by the dataset, and display this value in an informative print statement.

# %%
# Write your code here

# %% [markdown]
# #### Part 2
#
# Let's work on accessing particular kinds of data from `hcv_data`. First, isolate and print the 108th patient represented in the array.

# %%
# Write your code here

# %% [markdown]
# #### Part 3
#
# Now, isolate and print the columns in the dataset representing the age and albumin of all individuals represented.

# %%
# Write your code here

# %% [markdown]
# #### Part 4
#
# Now, let's get a little bit more intense. Use a for loop to loop through the columns representing the individual's age and each of the blood test values and print the minimum, maximum, and mean values of each column. You only need to print the values, not the column.
#
# *Hint*: There are some `NaN` (not-a-number, or missing data) values in this dataset, as often occurs in real-world data. The functions that you learned in the readings for today (`np.min`, `np.max`, and `np.mean`) are all negatively affected by `NaN` values. You'll need to use `np.nanmin`, `np.nanmax`, and `np.nanmean`, which ignore `NaN` values, instead. When you're working with your own data, always think about how missing data may affect your analysis.
#
# *Note*: Don't worry if you struggle with this one – it's genuinely harder than what I've asked you to do with NumPy before!

# %%
# Write your code here

# %% [markdown]
# #### Part 5
#
# I'm going to immediately reverse what I said above! One downside of NumPy arrays is that you can't label the columns. We'll learn about a package that helps with this soon, but for now we'll have to think about a work-around. In the code block below, adapt your code from Part 4 so that it prints *what* the column is along with the minimum, maximum, and mean values.
#
# *Hint*: Think extra lists...

# %%
# Write your code here

# %% [markdown]
# #### Part 6
#
# The reading didn't teach us how to filter arrays by a column value, but doing so can be incredibly valuable. Use the resource of your choice (a friend, Google, the AI chatbot of your choice) to learn how to filter. Then, use this knowledge to count the number of patients who fall into each Hepatitis-C status and display the values with informative print statements.

# %% [markdown]
# ---
#
# *[List the sources you used here, including all prompts and responses if a chatbot was used]*
#
# ---

# %%
# Write your code here

# %% [markdown]
# #### Part 7
#
# Pass the AI chatbot of your choice your code above and ask it if there is a more efficient way to write the code. If so, continue your interaction with the chatbot until you understand the new code. Paste the optimized version of your code below and write a one to two sentence description of what the new code does.

# %% [markdown]
# ---
#
# *[Name your chatbot and paste all interactions here – prompts and responses]*
#
# ---

# %%
# Paste your code here

# %% [markdown]
# ---
#
# *[Write your answer here]*
#
# ---

# %% [markdown]
# #### Part 8
#
# Find the average value of alanine transaminase (ALT) in each group of individuals by Hepatitis-C stage. Then, write a brief (1-2 sentence) description of what you see in the data.
#
# *Hint*: Again, you'll need to account for possible `NaN` values in your data.

# %%
# Write your code here

# %% [markdown]
# ---
#
# *[Write your answer here]*
#
# ---

# %% [markdown]
# #### Part 9
#
# Now that you've done some work with this dataset, try asking your own question! Think about some analysis you would like to do with the dataset; this should be more complicated than the work you did for Part 8, but easily done within a single code block. Below, in a few sentences, describe your proposed analysis.

# %% [markdown]
# ---
#
# *[Write your answer here]*
#
# ---

# %% [markdown]
# #### Part 10
#
# Now, use the AI chatbot of your choice to write code that completes the analysis you proposed in Part 9. Continue probing the model until you fully understand the code it produces. Then, in several sentences, describe what your code does and what your analysis reveals.

# %% [markdown]
# ---
#
# *[Name your chatbot and paste all interactions here – prompts and responses]*
#
# ---

# %%
# Paste your code here

# %% [markdown]
# ---
#
# *[Write your description here]*
#
# ---
