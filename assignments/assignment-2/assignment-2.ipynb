# %% [markdown]
# ## Assignment 2: Tic-Tac-Toe
# ***due Monday 07/06 at 9:00am (EST)***

# %% [markdown]
# ---
#
# **Name:** *[Your name here]*
# **ID:** *[Your netID here]*
# **Chatbots Used**: *[Chatbots you used here]*
#
# ---

# %% [markdown]
# ### Task 13

# %% [markdown]
# ---
#
# *[Write your answer here]*
#
# ---
