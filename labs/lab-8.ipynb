# %% [markdown]
# ## Lab 8: For + While Loops
#
# ***due Wednesday 07/08 at 11:30am (EST)***
#
# After finishing this lab, submit the `lab-8.ipynb` file on Canvas.

# %% [markdown]
# ---
#
# **Name:** *[Your name here]*
# **ID:** *[Your netID here]*
#
# ---

# %% [markdown]
# ### Less Than
#
# #### Part 1
#
# *Adapted from Cornell's CS 1110 (Spring 2025) materials*
#
# Write a function called `less_than_for` that takes the parameters `a_list` and `value` and returns the number of items in `a_list` that are strictly less than `value`.
#
# You can assume that `a_list` is a list of integers and that `value` is an integer. You *should not* edit the list.
#
# Write this function using a for loop.

# %%
def less_than_for(a_list, value):
    pass # Replace this statement with your code

# %% [markdown]
# #### Part 2
#
# As always, we should test any functions we write! For this question, I'll introduce a new Python element that allows us to write function tests.
#
# Basically, "the `assert` keyword lets you test if a condition in your code returns `True`, if not, the program will raise an AssertionError" (from [this site](https://www.w3schools.com/python/ref_keyword_assert.asp)). Note that if an `assert` test passes, *nothing* will happen.
#
# I've included one example of a test using `assert` below. Add another 4 tests, making sure to think about edge cases.

# %%
assert less_than_for([5, 9, 1, 7], 6) == 2

# Write your tests here

# %% [markdown]
# #### Part 3
#
# Write a function `less_than_while` that has the exact same functionality as `less_than_for` but uses a while loop instead.
#
# Run the same tests you designed in Part 2 on this function.

# %%
def less_than_while(a_list, value):
    pass # Replace this statement with your code

# %%
assert less_than_while([5, 9, 1, 7], 6) == 2

# Write your tests here

# %% [markdown]
# #### Part 4
#
# Compare and contrast your two `less_than` functions in a few sentences. Which felt more intuitive to write? Which do you think is easier to understand just by looking at it? Is there one you just like better?

# %% [markdown]
# ---
#
# *[Write your answer here]*
#
# ---

# %% [markdown]
# #### Part 5
#
# Ask the AI chatbot of your choice to write a function called `less_than` which takes the parameters `a_list` and `value` and returns the number of items in `a_list` that are strictly less than `value`. It can also assume that `a_list` is a list of integers and that `value` is an integer.
#
# Paste the function that the chatbot provides in the designated block below. Then, compare it with the two `less_than` functions you wrote in a few sentences. Is it similar to either of them? If so, do you think there's a reason it's more like one than the other? Look at the formatting and variables – do the chatbot's choices differ meaningfully from yours? How and why?
#
# *Note*: This isn't a very complicated function, so with high likelihood the chatbot produced correct code. However, (especially if it looks significantly different from the code you wrote and tested above) it's a good idea to test it separately!

# %% [markdown]
# ---
#
# *[Name your chatbot and paste all interactions here – prompts and responses]*
#
# ---

# %%
def less_than(a_list, value):
    pass # Replace this statement with your code

# %% [markdown]
# ---
#
# *[Write your answer here]*
#
# ---

# %% [markdown]
# ### Greater Than Next
#
# #### Part 1
#
# *Adapted from Cornell's CS 1110 (Spring 2025) materials*
#
#
# Write a function called `greater_than_next()` that takes a list of numbers (`lst`) and returns a list of the same length where the ith element of the returned list is `True` if the ith element of `lst` is greater than the next element of `lst` and False otherwise. The ith element should also be `False` if there is no next element.

# %%
def greater_than_next(lst):
    pass # Replace this statement with your code

# %% [markdown]
# #### Part 2
#
# *Adapted from Cornell's CS 1110 (Spring 2025) materials*
#
#
# Let's test the function! One test using `assert` is below. Write another 4 tests of `greater_than_next`, thinking about what edge cases you may need to cover.

# %%
assert greater_than_next([0, 2, 1, 1, 0]) == [False, True, False, True, False]

# Write your tests here

# %% [markdown]
# ### Reading Code
#
#
# #### Part 1
#
# ```python
# def index_summary(sentences):
#     indexed = ""
#
#     for s in range(len(sentences)):
#         indexed += str(s+1) + ". " + sentences[s] + "\n"
#
#     return indexed.strip()
# ```
#
# This small helper function was part of the codebase for a recent research project. It's a little bit weird to consider out of context, but as a function it's meant to exist as an independent, comprehensible unit.
#
# With the Python you've learned, you should be able to take a stab at understanding it! Look through the code closely and try to get an understanding of what it does. Then, write a couple sentence description of what the function does, specifically mentioning what type of data `sentences` likely contains and what the function returns.
#
# *Note*: Don't worry about getting it exactly right! This exercise is about learning to read code, not being able to do so perfectly.

# %% [markdown]
# ---
#
# *[Write your description here]*
#
# ---

# %% [markdown]
# #### Part 2
#
# Now, pass the AI chatbot of your choice the `index_summary` function and ask it to describe what it does.
#
# In a couple sentences, describe how the chatbot's description differs from or is similar to yours. What do you agree on? Is there anything you disagree on, and if so, who do you think is right?

# %% [markdown]
# ---
#
# *[Name your chatbot and paste all interactions here – prompts and responses]*
#
# ---

# %% [markdown]
# ---
#
# *[Paste the chatbot's description of the code here]*
#
# ---

# %% [markdown]
# ---
#
# *[Write your comparison here]*
#
# ---
