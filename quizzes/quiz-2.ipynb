# %% [markdown]
# ## Quiz 2
#
# ***Friday 07/03***
#
# Topics: Conditionals, Functions, Lists

# %% [markdown]
# ### Concept Questions

# %% [markdown]
# 1. Explain what boolean expressions are and what role they play in conditional statements. Include: which parts of conditionals use boolean expressions, 2-3 operators that may appear in boolean expressions, and examples of boolean expressions that use those operators.
# 2. Explain what the return statement does in a function and the differences between functions that do and don't include one. Include: what causes functions with + without return statements to stop executing, what happens when we print the result of calling both kinds of functions, and examples of functions of each kind.
# 3. Explain what aliasing is. Include: why aliasing matters for lists, two ways you may alias a list variable in your code, and a situation in which aliasing may be useful.

# %% [markdown]
# ### Explain this Code
# *Example code partially Claude generated*

# %% [markdown]
# 1. Explain what each line of the code does. Then, tell me what the print statement will print.
#
#     If you think the code would throw an error, identify it and explain what you think the code is *trying* to do.
#
#     ```python
#     def mystery(l, n):
#         if sum(l) % n == 0:
#             return True
#         else:
#             return False
#
#     print(mystery([1, 7, 5], 3))
#     ```

# %% [markdown]
# 2. Explain what each line of the code does. Then, tell me what the `orwell` and `result` variables will be equal to after the code runs.
#
#     If you think the code would throw an error, identify it and explain what you think the code is *trying* to do.
#
#     ```python
#     def mystery(l):
#         if int(l[-1]) > 12:
#             l[-1] = "12"
#
#     orwell = ["the", "clocks", "were", "striking", "13"]
#     result = mystery(orwell)
#     ```

# %% [markdown]
# 3. Explain what each line of the code does. Then, tell me what each print statement will print.
#
#     If you think the code would throw an error, identify it and explain what you think the code is *trying* to do.
#
#     ```python
#     def mystery(s, item):
#         l = s.split()
#         l.remove(item)
#         return " ".join(l)
#
#     print(mystery("Call me Ishmael.", "me"))
#     print(l)
#     ```

# %% [markdown]
# 4. Explain what each line of the code does. Then, give inputs that would cause each of the three `return` statements to run.
#
#     If you think the code would throw an error, identify it and explain what you think the code is *trying* to do.
#
#     ```python
#     def mystery(l):
#         if min(l) == max(l):
#             if len(l) > 1:
#                 return True
#             else:
#                 return False
#
#         return False
#     ```

# %% [markdown]
# 5. Explain what each line of code does. Then, tell me what the `vals` variable will be equal to after the code runs.
#
#     If you think the code would throw an error, identify it and explain what you think the code is *trying* to do.
#
#     ```python
#     def mystery(l, n):
#         if n not in l and not max(l) < n:
#             l.extend([n])
#             l.sort()
#
#     vals = [1, 4, 5, 8]
#     mystery(vals, 10)
#     mystery(vals, 7)
#     ```
