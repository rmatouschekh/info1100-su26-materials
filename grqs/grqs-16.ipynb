# %% [markdown]
# ## GRQs: Dataframes
# ***due Tuesday 07/28 at 11:30am (EST)***
#
# Answer each of the following questions with either the requested code or a multi-sentence written response. This assignment will be scored on completion.

# %% [markdown]
# ---
#
# **Name:** *[Your name here]*
# **ID:** *[Your netID here]*
#
# ---

# %%
# Run me before continuing!
# !pip install pandas
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 25.3 MB/s  0:00:00 eta 0:00:01
# ...
#
# [notice] A new release of pip is available: 26.0.1 -> 26.1.1
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ### Question 1
#
# Today's readings have introduced you to Pandas series and dataframes as a new way of managing and manipulating data. After a month of working with Python, what feels natural about Pandas? What feels weird? Why do you think that is?

# %% [markdown]
# ---
#
# *[Write your answer here]*
#
# ---

# %% [markdown]
# ### Question 2
#
# For this question, we'll be using the Bellevue Almshouse Dataset.
#
# The following excerpt from *Introduction to Cultural Analytics & Python* by Melanie Walsh introduces the dataset:
# >The dataset that we’re working with in this lesson is the Bellevue Almshouse Dataset, created by historian and DH scholar Anelise Shrout. It includes information about Irish-born immigrants who were admitted to New York City’s Bellevue Almshouse in the 1840s.
# >
# >The Bellevue Almshouse was part of New York City’s public health system, a place where poor, sick, homeless, and otherwise marginalized people were sent — sometimes voluntarily and sometimes forcibly. Devastated by widespread famine in Ireland, many Irish people fled their homes for New York City in the 1840s, and many of them ended up in the Bellevue Almshouse.
# >
# >We’re using the Bellevue Almshouse Dataset to practice data analysis with Pandas because we want to think deeply about the consequences of reducing human life to data. As Shrout argues in [her essay](https://crdh.rrchnm.org/essays/v01-10-re-humanizing-data/), this data purposely reduced people to bodies and “easily quantifiable aspects” in order to devalue their lives, potentially enacting “both epistemic and physical violence” on them.
# >
# >We want to think about how responsible data analysis requires more than just technical tools like Pandas. It also requires an interrogation of the data. Who collected this data? How and why was this data collected? What assumptions are present in this data? What are the consequences of this data in the world? What does this data reflect about the world? For example, Shrout claims that the “Bellevue administrators framed any ailments or difficulties inmates might have had as a consequence of [their immigration] status” — perhaps best exemplified by the fact that a frequent “disease” in the dataset is “recent emigrant.” Below we’re going to explore the prevalence of “recent emigrant” in the data as well as other salient patterns.
#
# Frequently, Pandas dataframes are used to store and analyze data stored in `.csv` files. Although today's readings taught you a lot about how dataframes work and how to access and manipulate data in them, it didn't teach you how to load in data from a `.csv`, which is how they are commonly initialized in real-world code.
#
# You should've downloaded the dataset as `bellevue_almshouse_modified.csv`. The following series of questions will ask you to load in this file and then perform a series of analysis operations on the resulting data. You may use any outside resource (e.g. Google, an AI chatbot, a knowledgable friend) to learn the necessary Pandas syntax, as long as you cite all resources and include any chatbot prompts and responses below.

# %% [markdown]
# ---
#
# *[List the sources you used here – including any chatbot prompts and responses]*
#
# ---

# %% [markdown]
# First, import the Pandas package and load the Bellevue Almshouse dataset as a dataframe. Then, find how many people are included in the dataset.

# %%
# Write your code here

# %% [markdown]
# Determine the range of ages (youngest to oldest) and the average age of the individuals described in the dataset.

# %%
# Write your code here

# %% [markdown]
# There are many things considered *diseases* by the people who originally kept the Bellevue Almshouse records. Find all of the unique "diseases" included in the dataset and the most commonly listed "disease."

# %%
# Write your code here

# %% [markdown]
# The gender of each individual is included in the dataset. What proportion of the people described were marked as women (`w`)??

# %%
# Write your code here

# %% [markdown]
# The `children` column in the dataset contains notes describing each person's children, if they had any. How many of the individuals in the dataset are marked as having children? What proportion of the dataset is this?

# %%
# Write your code here

# %% [markdown]
# There are many, many additional interesting things that you could analyze about this dataset. Determine one additional dataset property of your choice below, and include a comment or print statement describing what property you're calculating.

# %%
# Write your code here

# %% [markdown]
# ### Question 3
#
# Dataframes are very frequently used in real-world research pipelines. Imagine a research project that you would be interested in undertaking (or at least reading about!) that would need to use Pandas dataframes. Consider the specific data you would need, what kinds of analysis you would want to perform, and the tools you would need to perform that analysis.
#
# Describe your theoretical project in a paragraph (at least 3-5 sentences). Include why you think dataframes would be the best way of storing your data.

# %% [markdown]
# ---
#
# *[Write your answer here]*
#
# ---
