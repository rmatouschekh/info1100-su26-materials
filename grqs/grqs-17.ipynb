# %% [markdown]
# ## GRQs: Data Visualization (Principles)
# ***due Wednesday 07/29 at 11:30am (EST)***
#
# Answer each of the following questions with either the requested code or a multi-sentence written response. This assignment will be scored on completion.

# %% [markdown]
# ---
#
# **Name:** *[Your name here]*
# **ID:** *[Your netID here]*
#
# ---

# %% [markdown]
# ### Question 1
#
# What was the most surprising thing you learned in today's reading? Why did it surprise you?

# %% [markdown]
# ---
#
# *[Write your answer here]*
#
# ---

# %% [markdown]
# ### Question 2.1
#
# Consider the rainbow color palette, an example of which you can see below. If you had to guess, what would you say the usual advice about using rainbow color palettes in visualizations is? What kind of data or visualizations should rainbow palettes be used with, if any?

# %% [markdown]
# <div style="text-align: center;">
#     <img src="grqs-files/rainbow_palette.png" alt="drawing" width="300"/>
# </div>

# %% [markdown]
# ---
#
# *[Write your answer here]*
#
# ---

# %% [markdown]
# ### Question 2.2
#
# Let's do some research about rainbow color palettes! Using the source of your choice, find the answers to the questions above. Describe your findings in a few sentences.

# %% [markdown]
# ---
#
# *[List the sources you used here – including any chatbot prompts and responses]*
#
# ---

# %% [markdown]
# ---
#
# *[Write your answer here]*
#
# ---

# %% [markdown]
# ### Question 3
#
# Go to https://dialed.gg. Click the calendar symbol in the bottom right of the black square. This will take you to a daily color quiz, which asks you to try and match five colors using hue, saturation, and brightness sliders.
#
# Take the quiz! Then, write a couple of sentences describing your reaction – was it harder than you expected? Easier? Why is that?

# %% [markdown]
# ---
#
# *[Write your quiz score here]*
#
# ---

# %% [markdown]
# ---
#
# *[Write your reflection here]*
#
# ---

# %% [markdown]
# ### Question 4
#
# Consider the visualization below. Based on what you just learned, write a critique of the visualization, including 2-3 things you think it does well and 2-3 things it could improve.

# %% [markdown]
# <div style="text-align: center;">
#     <img src="grqs-files/data-viz-1.png" alt="drawing" width="600"/>
# </div>

# %% [markdown]
# ---
#
# *[Write your analysis here]*
#
# ---
