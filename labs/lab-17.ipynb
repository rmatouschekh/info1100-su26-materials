# %% [markdown]
# ## Lab 17: Dataframes
#
# ***due Wednesday 07/29 at 11:30am (EST)***
#
# After finishing this lab, submit the `lab-17.ipynb` file on Canvas.

# %% [markdown]
# ---
#
# **Name:** *[Your name here]*
# **ID:** *[Your netID here]*
#
# ---

# %% [markdown]
# ### Loading Complex Data
#
# In Lab 10, I wrote some complex code to load the Bellevue Almshouse dataset, clean it, and convert it into a dictionary. At the time, I told you to gloss over the code because we hadn't learned the necessary package for understanding it. Now that we've learned about Pandas, we're way closer to being able to understand what I did! But, some of the syntax is still new.
#
# Using the source of your choice (a friend, Google, an AI chatbot), figure out what each individual line of code does, and add relevant comments explaining each. Then, in a couple of sentences, describe what syntax was new (i.e., wasn't introduced in the readings, lecture, or GRQs).

# %%
import pandas as pd

# Add your comments explaining each of the following lines of code (you can replace this statement if desired!)
bellevue_df = pd.read_csv("lab-files/bellevue_almshouse_modified.csv")
bellevue_df["name"] = bellevue_df["first_name"] + " " + bellevue_df["last_name"]
bellevue_df = bellevue_df.drop(columns=["first_name", "last_name"])\
    .drop_duplicates(subset=["name"])\
    .set_index("name")
bellevue_df["children"] = bellevue_df["children"].fillna("")
bellevue_dict = bellevue_df.to_dict('index')

# %% [markdown]
# ---
#
# *[List the sources you used here, including all prompts and responses if a chatbot was used.
# &emsp;&emsp;Specifically, note what source or chatbot response described which line]*
#
# ---

# %% [markdown]
# ---
#
# *[Write your answer here]*
#
# ---

# %% [markdown]
# ### Books, Books, Books
#
# #### Part 1
#
# In your `lab-files` folder there is a dataset called `book_dataset.csv`. Again, this is a dataset that was used in an actual research project of mine!
#
# In the code cell below, read the `csv` into a Pandas dataframe called `book_df`.

# %%
# Write your code here

# %% [markdown]
# #### Part 2
#
# Now, let's figure out what this dataset represents. Explore the dataset in the code cell below – but stick to code you've already learned.
#
# Then, describe the dataset. Specifically, explain what kind of data each row represents and what data each column contains.

# %%
# Write your code here

# %% [markdown]
# ---
#
# *[Describe the dataset here]*
#
# ---

# %% [markdown]
# #### Part 3
#
# Think about what kinds of research questions the dataset above may help in answering. Specifically, come up with three broader research goals this dataset may help contribute to answering.
#
# *Note*: The goal of this exercise is to get you to think about how to use the data you have to answer real questions, not to get you to try and guess what research I did!

# %% [markdown]
# ---
#
# *[Write your answer here]*
#
# ---

# %% [markdown]
# #### Part 4
#
# The grand goals you've (hopefully) thought of above are a little bit out of the scope of this lab. Let's do some smaller analyses instead. For these questions, you may use any outside sources (e.g., a friend, Google, an AI chatbot).
#
# Find the number of books written by each unique author in the dataset, and then print these values.
#
# *Note*: Some books may be written by multiple authors. Make sure to treat each of those authors as unique entities in your analysis!

# %% [markdown]
# ---
#
# *[List the sources you used here – including any chatbot prompts and responses]*
#
# ---

# %%
# Write your code here

# %% [markdown]
# #### Part 5
#
# Again, if necessary, you may use any outside sources (e.g., a friend, Google, an AI chatbot) to answer this question.
#
# Determine if there is a meaningful correlation between the number of chapters and the word count of each book. In a single sentence, quickly describe the result of your code.
#
# *Hint*: If you didn't guess it earlier, the `wc` column contains the word count of each novel.

# %% [markdown]
# ---
#
# *[List the sources you used here – including any chatbot prompts and responses]*
#
# ---

# %%
# Write your code here

# %% [markdown]
# ---
#
# *[Describe what you find here]*
#
# ---

# %% [markdown]
# #### Part 6
#
# Again, if necessary, you may use any outside sources (e.g., a friend, Google, an AI chatbot) to answer this question.
#
# Find the average word count of the `summary` column in the dataset.

# %% [markdown]
# ---
#
# *[List the sources you used here – including any chatbot prompts and responses]*
#
# ---

# %%
# Write your code here
