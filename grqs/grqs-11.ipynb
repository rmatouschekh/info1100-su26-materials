# %% [markdown]
# ## GRQs: Tuples + Sets
# ***due Wednesday 07/15 at 11:30am (EST)***
#
# Answer each of the following questions with either the requested code or a multi-sentence written response. This assignment will be scored on completion.

# %% [markdown]
# ---
#
# **Name:** *[Your name here]*
# **ID:** *[Your netID here]*
#
# ---

# %% [markdown]
# ### Question 1.1
#
# Write a function called `num_unique_words` that finds the number of unique words in a string. For this function, a word is anything separated by a space from the rest of the string. Include 2-3 tests of your function.
#
# *Hint*: You should be able to write this function in one line of code.

# %%
# Write your function here

# %%
# Write your tests

# %% [markdown]
# ### Question 1.2
#
# Ask an AI chatbot to write tests for your `num_unique_words` function. What do you think of the resulting tests? Are they better than what you would've created? Worse?

# %% [markdown]
# ---
#
# *[Name your chatbot and paste all interactions here – prompts and responses]*
#
# ---

# %%
# Paste the generated tests here

# %% [markdown]
# ---
#
# *[Write your reflection here]*
#
# ---

# %% [markdown]
# ### Question 2
#
# *Designed with Claude Opus 4.8*
#
# Today's reading mentioned that Python's built-in `divmod` function returns two values at once by packaging them into a tuple. Let's write our own version of this function.
#
# In the code block below, write a function called `divide_mod`, which takes two integers `a` and `b` as arguments and returns a tuple containing the quotient (`a // b`) and the remainder (`a % b`). Then, in the second code block, call your function with two integer values, use tuple assignment to unpack the result into two variables, and print the quotient and the remainder on two separate lines.

# %%
# Write your function here

# %%
# Call your function here

# %% [markdown]
# ### Question 3
# *Adapted from Exercise 18.11.2 in "Think Python" by Allen B. Downey*
#
# One of your earlier GRQs asked you to write a function called `uses_none` that takes a word and a string of forbidden letters, and returns `True` if the word does not use any of the letters. Here’s a solution.
#
# ```python
# def uses_none(word, forbidden):
#     for letter in word.lower():
#         if letter in forbidden.lower():
#             return False
#     return True
# ```
#
# Write a version of this function that uses `set` operations instead of a `for` loop.
#
# *Hint*: Consider common set functions. Feel free to use outside resources to figure out how to implement any functions you need that you haven't learned yet.

# %%
# Write your function here

# %% [markdown]
# ---
#
# *[List any external resources used]*
#
# ---

# %% [markdown]
# ### Question 4
# *Adapted from CS 1110 materials*
#
# Figuring out how tuples behave can be difficult, but as always it's good to have an intuitive sense how they work. Without running any of the code, try and fill in each of the blanks in the following table.

# %% [markdown]
# Consider the tuple `t = (9, 8, 7)`.
#
# | Statement | Output |
# | :--- | :--- |
# | `t[-1]` | <span style="color:#33cc33">**a**</span> |
# | `3 in t` | <span style="color:#33cc33">**b**</span> |
# | `t[1:]` | <span style="color:#33cc33">**c**</span> |
# | `t[2] = 3` | <span style="color:#33cc33">**d**</span> |
# | `sorted(t)` | <span style="color:#33cc33">**e**</span> |
# | `t[`<span style="color:#33cc33">**f**</span>`]` | `8` |
# | `t[`<span style="color:#33cc33">**g**</span>`:]` | `(7,)` |
# | <span style="color:#33cc33">**h**</span>`(reversed(t))` | `(7, 8, 9)` |

# %% [markdown]
# <span style="color:#33cc33">**a**</span>: *[Write value here]*

# %% [markdown]
# <span style="color:#33cc33">**b**</span>: *[Write value here]*

# %% [markdown]
# <span style="color:#33cc33">**c**</span>: *[Write value here]*

# %% [markdown]
# <span style="color:#33cc33">**d**</span>: *[Write value here]*

# %% [markdown]
# <span style="color:#33cc33">**e**</span>: *[Write value here]*

# %% [markdown]
# <span style="color:#33cc33">**f**</span>: *[Write value here]*

# %% [markdown]
# <span style="color:#33cc33">**g**</span>: *[Write value here]*

# %% [markdown]
# <span style="color:#33cc33">**h**</span>: *[Write value here]*
