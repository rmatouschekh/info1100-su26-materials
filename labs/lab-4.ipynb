# %% [markdown]
# ## Lab 4: Strings
#
# ***due Friday 06/26 at 11:30am (EST)***
#
# After finishing this lab, submit the `lab-4.ipynb` file on Canvas.

# %% [markdown]
# ---
#
# **Name:** *[Your name here]*
# **ID:** *[Your netID here]*
#
# ---

# %% [markdown]
# ### Finding Substrings
#
# #### Part 1
#
# *Adapted from Cornell's CS 1110 (Spring 2025) materials*
#
# Your job is to write code that does the following:
#
# Take the string stored in the variable `s` and extract the first substring of `s` between two double quotes. Store the extracted substring in the variable `quote`. For example, if `s = 'A "B C" D'`, you should extract `'B C'`. If there are multiple substrings wrapped in quotes in `s`, extract the first one, so if `s = 'A "B C" D "E F"'`, it should still return `'B C'`.
#
# A quote character is one that is inside a string, not one that delimits it.  We typically use single quotes (') to delimit a string if want to use a double quote character (") inside of it. You can assume that `s` is a string containing at least two double quotes.
#
# *Hint*: Look up the `find` function. Try changing the value of `s` to different strings to test your code.

# %%
s = 'A "B C" D'

# Write your code here

# %% [markdown]
# #### Part 2
#
# In the previous part of this question, I specified that the variable `s` will always be a string that contains at least two double quotes. Let's think about what we'd need to do if that wasn't true!
#
# In your own words, hypothesize what your code would need to do in order to handle values of `s` that do *not* necessarily have at least two double quotes. What kind of Python syntax might we need to learn in order to handle those strings? How might your program check for missing quotation marks before trying to extract substrings?

# %% [markdown]
# ---
#
# *[Write your answer here]*
#
# ---

# %% [markdown]
# #### Part 3
#
# Let's try to make your code handle cases when `s` may not have at least two sets of double quotes. Take the code you wrote for Part 1 and prompt the AI chatbot of your choice to edit it so it handles cases where `s` doesn't have at least two quotation marks.
#
# Take a look at the code it produces. If you don't understand something, try following up with the chatbot to get an explanation of the new lines of code. Make sure to test your code to confirm it *does* handle those cases where `s` doesn't have at least two double quotes without throwing an error.
#
# What did the chatbot do? What's new to you, and do you understand what it did? How does the produced code align with what you proposed above?

# %% [markdown]
# ---
#
# *[Name your chatbot and paste all interactions here – prompts and responses]*
#
# ---

# %%
# Paste the edited version of your code here

# %%
# Write your tests here

# %% [markdown]
# ---
#
# *[Write your analysis of the generated code here]*
#
# ---
