# %% [markdown]
# ## Lab 11: Regular Expressions
#
# ***due Wednesday 07/15 at 11:30am (EST)***
#
# After finishing this lab, submit the `lab-11.ipynb` file on Canvas.

# %% [markdown]
# ---
#
# **Name:** *[Your name here]*
# **ID:** *[Your netID here]*
#
# ---

# %% [markdown]
# ### Go Fish
#
# *Designed with Jacob A. Matthews*
#
# In the code block below, I've loaded in a text file (`lab-files/go-fish.txt`) to a string called `search`. This document contains 100 different phone numbers. Throughout this lab, we'll use regular expressions to identify all of the phone numbers!

# %%
import os

with open(os.path.join("lab-files", "go-fish.txt")) as f:
    search = f.read()

# %% [markdown]
# #### Part 1
#
# A large proportion of the 100 phone numbers in `search` are of the format xxx-xxx-xxxx, where each x is an integer. Try to write a regular expression that matches that format *without* the help of AI.
#
# You may need some regex tricks that you didn't learn in the reading for today – [this site](https://www.geeksforgeeks.org/python/regular-expression-python-examples/) should give you any additional information you need.

# %% [markdown]
# ---
#
# *[Write your regular expression here]*
#
# ---

# %% [markdown]
# #### Part 2
#
# Let's use that regular expression to extract the phone numbers of the format xxx-xxx-xxxx from `search`! You'll want to use a function from the `re` package to do so. You should create a list of all of the phone numbers of that format and save it in a variable, then print the # of phone numbers you found of the right format.
#
# The [same source](https://www.geeksforgeeks.org/python/regular-expression-python-examples/) from Part 1 can give you some pointers towards which function to use!

# %%
import re

# Write your code here

# %% [markdown]
# #### Part 3
#
# Now, let's try to find all of the phone number formats in `search` that aren't xxx-xxx-xxxx! If you're having fun, you can do this by hand (just open up `go-fish.txt` and look at what's in there!) or, you can paste the contents of `go-fish.txt` into the AI chatbot of your choice and ask it to find all of the extra phone number formats.
#
# List each new format in the designated section below, using x's to replace each digit.

# %% [markdown]
# ---
#
# *[Name your chatbot and paste all interactions here – prompts and responses]*
#
# ---

# %% [markdown]
# ---
#
# *List the alternate phone number formats here*
#
# ---

# %% [markdown]
# #### Part 4
#
# Now, let's write regex statements that match each of the new formats you've identified above. Again, you can do this by hand if you're having fun, or you can ask an AI chatbot to generate regular expressions to match each new format.
#
# Then, in the code block below, extract the phone numbers of each format from `search` and print the number of extracted phone numbers of that type! (Try and make the print statements informative, i.e. "There are *n* phone numbers of type –".)

# %% [markdown]
# ---
#
# *[Name your chatbot and paste all interactions here – prompts and responses]*
#
# ---

# %% [markdown]
# ---
#
# *[List the regex for each additional phone number format here]*
#
# ---

# %%
# Write your code here

# %% [markdown]
# #### Part 5
#
# Remember that there should be 100 phone numbers total! Have you found all of them? If so, leave the blocks below blank. If not, use whatever method you like to try and find the remaining numbers and extract them from `search`.

# %% [markdown]
# ---
#
# *[Name your chatbot and paste all interactions here – prompts and responses]*
#
# ---

# %% [markdown]
# ---
#
# *[List the regex for each additional phone number format here]*
#
# ---

# %%
# Write your code here

# %% [markdown]
# #### Part 6
#
# So far, we've gone very step-by-step by discovering each phone number format and then extracting them individually. But what happens if we give the chatbot the entire task at once?
#
# Again, take the AI chatbot of your choice. In a new chat, paste the entire text of `go-fish.txt` and ask it to write a Python script that uses regular expressions to extract all of the phone numbers.
#
# Then, reflect on the differences between asking the chatbot to do the whole task at once and the step-by-step approach we went with before. Did the chatbot get all of the phone numbers when asked to extract them all at once? Does the code look similar to what happened when we generated it step-by-step, or is it different? Do you understand the new code?

# %% [markdown]
# ---
#
# *[Name your chatbot and paste all interactions here – prompts and responses]*
#
# ---

# %%
# Paste the code to extract all phone numbers here

# %% [markdown]
# ---
#
# *[Write your reflection here]*
#
# ---
