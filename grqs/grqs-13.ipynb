# %% [markdown]
# ## GRQs: Classes + Objects (Part 2)
# ***due Tuesday 07/21 at 11:30am (EST)***
#
# Answer each of the following questions with either the requested code or a multi-sentence written response. This assignment will be scored on completion.

# %% [markdown]
# ---
#
# **Name:** *[Your name here]*
# **ID:** *[Your netID here]*
#
# ---

# %% [markdown]
# ### Question 1
#
# How do you feel about learning about object-oriented programming? What feels weird, and what feels natural?

# %% [markdown]
# ---
#
# *[Write your answer here]*
#
# ---

# %% [markdown]
# ### Question 2
# *Adapted from Exercise 15.10.2 in "Think Python" by Allen B. Downey*
#
# We are going to write a `Date` class and several methods that work with `Date` objects.
#
# *Hint*: You might find it useful write a method called `to_tuple` that returns a tuple that contains the attributes of a `Date` object in year-month-day order.

# %% [markdown]
# **2.1:** Write a definition for a `Date` class that represents a date – that is, a year, month, and day of the month.

# %%
# Write your code here

# %% [markdown]
# **2.2:** Write an `__init__` method that takes `year`, `month`, and `day` as parameters and assigns the parameters to attributes. Create an object that represents June 22, 1933.

# %%
# Write your code here

# %% [markdown]
# **2.3:** Write a `__str__` method that uses an f-string to format the attributes and returns the result. If you test it with the `Date` you created, the result should be `1933-06-22`.

# %%
# Write your code here

# %% [markdown]
# **2.4:** Write a method called `is_after` that takes two `Date` objects and returns `True` if the first comes after the second. Create a second object that represents September 17, 1933, and check whether it comes after the first object.

# %%
# Write your code here

# %% [markdown]
# ### Question 3
#
# Consider a class that you might want to define in your own program. Think about what attributes and methods you might want that class to have. Feel free to use the example you came up with for the last set of GRQs. Then, ask the AI chatbot of your choice to generate the class for you. How did it do? Is there anything it generated that you don't understand?

# %% [markdown]
# ---
#
# *[Name your chatbot and paste all interactions here – prompts and responses]*
#
# ---

# %%
# Paste your generated class + methods here

# %% [markdown]
# ---
#
# *[Write your analysis here]*
#
# ---
