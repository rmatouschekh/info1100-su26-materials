# %% [markdown]
# ## Lab 16: Reading + Writing Files
#
# ***due Friday 07/24 at 11:30am (EST)***
#
# After finishing this lab, submit the `lab-16.ipynb` file and each of your test text files (created for Get One Less – Part 2) on Canvas.

# %% [markdown]
# ---
#
# **Name:** *[Your name here]*
# **ID:** *[Your netID here]*
#
# ---

# %% [markdown]
# ### Get One Less
#
# #### Part 1
#
# *Adapted from Cornell's CS 1110 (Spring 2025) materials*
#
# Write a function called `get_one_less` that takes in a filename as an argument (`filename`). The function should subtract 1 from each line of the file that contains a numeric value and saves it the new text to the same filename. Any lines that contain a non-numeric value should be left as-is.
#
# You can assume that `filename` refers to an existing file and that each file contains a single *value* on each line.
#
# I have provided one file (`lab-16-test.txt` file in `lab-files`) you can use to start testing the function. Make sure that the contents of the file have changed as the function requires after running the function on it.
#
# *Note*: Try to make sure data types stay the same when you save the new file. That is, numeric values that were integers should stay integers, and floats should stay floats.

# %%
def get_one_less(filename):
    pass # Write your code here

# %%
import os

get_one_less(os.path.join("lab-files", "lab-16-test.txt"))

# %% [markdown]
# #### Part 2
#
# I've provided one text file that tests your function behavior, but it only checks the function's standard behavior, and not any edge cases. Create an additional three text files (`lab-16-test-2.txt`, `lab-16-test-3.txt`, `lab-16-test-4.txt`) that test your function's edge case performance.
#
# Describe in a few sentences what each of your new files test. Then, in the code block below, use those files to test your function.

# %% [markdown]
# ---
#
# *[Write your description here]*
#
# ---

# %%
# Write your tests here

# %% [markdown]
# #### Part 3
#
# We may not always be able to guarantee that the filenames passed to functions refer to real, existing files. Let's figure out how to test if filenames refer to actual files!
#
# Ask the AI chatbot of your choice how to check whether a path refers to an existing file. Then, adapt your `get_one_less` function so that it checks whether the `filename` argument refers to a real file and then describe in a couple of sentences what the new syntax in your function does.

# %%
# Write your new function here

# %% [markdown]
# ---
#
# *[Write your description here]*
#
# ---

# %% [markdown]
# ### Says Who?
#
# *Note*: This exercise will ask you to work with a corpus of poems. Note that some of these poems may address sensitive topics. While you won't be asked to directly deal with the contents of the poems, please (please!) reach out to me if you want warnings about what topics in particular may be addressed.
#
# #### Part 1
#
# In the `lab-files` folder, there is a subfolder called `poems` which contains a number of text files, each of which contains a poem.
#
# In the code block below, create a list of the poems stored in the folder `poems`. You may save the poems in whatever format you think is most useful for future analysis. Finally, print how many poems are in the subfolder in an informative statement.

# %%
# Write your code here

# %% [markdown]
# #### Part 2
#
# Each poem file contains the poem's title, author, and then the poem's lines in a standard format.
#
# Explore the data you loaded and saved in Part 1 to figure out the poems' format. Then, briefly describe what that format is.

# %%
# Write your exploration code here

# %% [markdown]
# ---
#
# *[Write your description here]*
#
# ---

# %% [markdown]
# #### Part 3
#
# Now, given what you discovered in Part 2, use a dictionary to count how many poems each unique author has in the `poems` folder.

# %%
# Write your code here

# %% [markdown]
# #### Part 4
#
# Let's use our dictionary to print the authors represented in the dataset in order by how many poems they wrote.
#
# To do this, first use the resource of your choice (a friend, Google, and AI chatbot) to discover how to sort dictionaries by value. Then, in the code block below, print each of the author names and poem counts in descending order. Finally, describe in a couple of sentences how your code works.

# %% [markdown]
# ---
#
# *[List the sources you used here, including all prompts and responses if a chatbot was used]*
#
# ---

# %%
# Write your code here

# %% [markdown]
# ---
#
# *[Write your description here]*
#
# ---

# %% [markdown]
# #### Part 5
#
# Finally, write a loop that counts and prints the number of *stanzas* in each poem. Use what you learned by looking at the poem structures in Part 2 to identify and count stanzas.

# %%
# Write your code here
