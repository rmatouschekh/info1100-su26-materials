# %% [markdown]
# ## GRQs: Functions
# ***due Wednesday 07/01 at 11:30am (EST)***
#
# Answer each of the following questions with either the requested code or a multi-sentence written response. This assignment will be scored on completion.

# %% [markdown]
# ---
#
# **Name:** *[Your name here]*
# **ID:** *[Your netID here]*
#
# ---

# %% [markdown]
# ### Question 1
#
# Section 3.8 of the reading provides some reasons that you might want to use functions when coding. Think about programs you want to create and when functions might be useful. Describe one such hypothetical use case for functions below.
#
# *Note:* You don't need to know how exactly you would write the code you're thinking about! Feel free to imagine beyond the boundaries of what we've learned so far.

# %% [markdown]
# ---
#
# *[Write your answer here]*
#
# ---

# %% [markdown]
# ### Question 2
#
# What does the following function do? Try running it with different arguments to see what happens!
#
# *Note:* The arguments are meant to be numbers. If you want to explore more, see what happens if you use strings!

# %%
# Function drafted by GPT 5.3
def mystery_func(a, b, c):
    if (a <= b and b <= c) or (c <= b and b <= a):
        return b
    elif (b <= a and a <= c) or (c <= a and a <= b):
        return a
    else:
        return c

# %% [markdown]
# ---
#
# *[Write your answer here]*
#
# ---

# %% [markdown]
# ### Question 3
# *Adapted from Exercise 3.11.2 in "Think Python" by Allen B. Downey*
#
# Write a function named `print_right` that takes a string named `text` as a parameter and prints the string with enough leading spaces that the last letter of the string is in the 40th column of the display.
#
# *Hint:* Use the `len` function, the string concatenation operator (`+`) and the string repetition operator (`*`).
#
# Here’s an example that shows how it should work:
# ```python
# print_right("Monty")
# print_right("Python's")
# print_right("Flying Circus")
# ```
#
# Output:
# ```
#                                    Monty
#                                 Python's
#                            Flying Circus
# ```
#
# Once you've written your `print_right` function, give a brief explanation of what the value of `x` would be if you set `x = print_right('Monty')` and why. Feel free to experiment with the code to figure it out!

# %%
# Write your code here

# %% [markdown]
# ---
#
# *[Write your explanation here]*
#
# ---

# %% [markdown]
# ### Question 4
#
# The following function has a few errors! Using the AI chatbot of your choice, try to fix the bugs. Then, explain in your own words what the errors were and how you fixed it. When the function works properly, all of the provided print statements should return `True` and the code should throw no errors.
#
# Mark the changes you made to the code with comments!

# %%
# Check if a 3-digit number is a palindrome – function drafted by GPT 5.3
def is_three_digit_palindrome(n):
    first = n / 100
    last = n % 100
    if first = last:
        return True
# Out:
#   Cell In[24], line 5
#     if first = last:
#        ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
# Tests
print(is_three_digit_palindrome(103) == False)
print(is_three_digit_palindrome(454) == True)
print(is_three_digit_palindrome(934) == False)
print(is_three_digit_palindrome(777) == True)
# Out:
# True
# True
# True
# True

# %% [markdown]
# ---
#
# *[Name your chatbot and paste all interactions here – prompts and responses]*
#
# ---

# %% [markdown]
# ---
#
# *[Write your explanation of the error here]*
#
# ---
