# %% [markdown]
# ## Lab 2: Types + Expressions
#
# ***due Wednesday 06/24 at 11:30am (EST)***
#
# After finishing this lab, submit the `lab-2.ipynb` file on Canvas.

# %% [markdown]
# ---
#
# **Name:** *[Your name here]*
# **ID:** *[Your netID here]*
#
# ---

# %% [markdown]
# ### Four Fours
# *Adapted from Harvey Mudd's CS 5 (Fall 2025) materials*
#
# This problem asks you to write a bunch of arithmetic expressions that will print each integer value... using *exactly* four fours! The code block below has examples for 0, 1, and 2.
#
# Your job is to finish the first decade (0-10) **without** the aid of AI. Then, you can use the AI chatbot of your choice to find the expressions for the second decade (11-20)! Remember to paste all interactions you have with the AI chatbot in the designated markdown block. You aren't by any means required to use AI – if you're having fun doing it by hand, keep going!
#
# You can use any of the following arithmetic operations:
# - `+` (addition)
# - `-` (subtraction)
# - `*` (multiplication)
# - `/` (division)
# - `( )` (parentheses for grouping)
# - `**` (power / exponentiation)
# - `sqrt(4)` (square root)
# - `factorial(4)` (factorial)
#
# *Hints*:
# - Results with decimal values are permitted – for this exercise 1 and 1.0 are the same!
# - You can use 44 and 4.4, each of which will count as two fours, or .4 and <span style="text-decoration: overline;">.4</span>, which counts as one four. To access <span style="text-decoration: overline;">.4</span>, use the `pt_four_bar` value.

# %%
from math import sqrt, factorial

pt_four_bar = .4444444444444444 

print("Zero is", 4+4-4-4)
print("One is", (4/4) * (4/4))
print("Two is", 4/4 + (4/4))

# Fill in these print statements *without* using AI
print("Three is", 0)
print("Four is", 0)
print("Five is", 0)
print("Six is", 0)
print("Seven is", 0)
print("Eight is", 0)
print("Nine is", 0)
print("Ten is", 0)

# Fill in these print statements – use AI if you want!
print("Eleven is", 0)
print("Twelve is", 0)
print("Thirteen is", 0)
print("Fourteen is", 0)
print("Fifteen is", 0)
print("Sixteen is", 0)
print("Seventeen is", 0)
print("Eighteen is", 0)
print("Nineteen is", 0)
print("Twenty is", 0)
# Out:
# Zero is 0
# One is 1.0
# Two is 2.0
# Three is 0
# Four is 0
# Five is 0
# Six is 0
# Seven is 0
# Eight is 0
# Nine is 0
# Ten is 0
# Eleven is 0
# Twelve is 0
# Thirteen is 0
# Fourteen is 0
# Fifteen is 0
# Sixteen is 0
# Seventeen is 0
# Eighteen is 0
# Nineteen is 0
# Twenty is 0

# %% [markdown]
# ---
#
# *[Name your chatbot and paste all interactions here – prompts and responses]*
#
# ---
