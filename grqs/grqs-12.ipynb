# %% [markdown]
# ## GRQs: Classes + Objects (Part 1)
# ***due Thursday 07/16 at 11:30am (EST)***
#
# Answer each of the following questions with either the requested code or a multi-sentence written response. This assignment will be scored on completion.

# %% [markdown]
# ---
#
# **Name:** *[Your name here]*
# **ID:** *[Your netID here]*
#
# ---

# %% [markdown]
# ### Question 1
#
# As today's readings said, classes are in many ways essentially programmer-defined data types that can have associated attributes and functions. What are some classes you might want to define? If you've declared a major that isn't CS or IS, think about what things common to your field you might want to represent in code.
#
# Write a few sentence description of a class you might want to define and why. Include what attributes and functions you think you'd want!

# %% [markdown]
# ---
#
# *[Write your answer here]*
#
# ---

# %% [markdown]
# ### Question 2
# *Adapted from Exercise 14.11.2 in "Think Python" by Allen B. Downey*
#
# Consider the `Time` object defined in today's reading from *Think Python* (and pasted below). Write a function called `subtract_time` that takes two `Time` objects and returns the interval between them in seconds – assuming that they are two times during the same day. Then, write 2-3 tests for your function.

# %%
class Time:
    """Represents a time of day."""

def make_time(hour, minute, second):
    time = Time()
    time.hour = hour
    time.minute = minute
    time.second = second
    return time

# %%
# Write your function here

# %%
# Write your tests here

# %% [markdown]
# ### Question 3
#
# Some distinctions were introduced into today's reading that can be tricky to fully understand. For each of the following questions, do some research using whatever outside source you want (Google, AI, a friend, etc) to figure out what the *difference* between the two given terms is and then explain this difference in 1-2 sentences.

# %% [markdown]
# **3.1:** What is the difference between a class and a type?

# %% [markdown]
# ---
#
# *[Write your answer here]*
#
# ---

# %% [markdown]
# **3.2:** What is the difference between an object and an instance?

# %% [markdown]
# ---
#
# *[Write your answer here]*
#
# ---

# %% [markdown]
# **3.3:** What is the difference between a variable and an attribute?

# %% [markdown]
# ---
#
# *[Write your answer here]*
#
# ---

# %% [markdown]
# ---
#
# *[List the sources you used in answering each question here]*
#
# ---

# %% [markdown]
# ### Question 4
#
# Define your own `Pet` class, then write a `make_pet` function that takes 3–4 attributes as parameters, assigns them to a new `Pet` object, and returns it. Use `make_pet` to create two different pets.

# %%
# Write your Pet class here and function here

# %%
# Create your Pet instances here
