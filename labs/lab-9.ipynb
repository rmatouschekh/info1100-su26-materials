# %% [markdown]
# ## Lab 9: Recursion
#
# ***due Thursday 07/09 at 11:30am (EST)***
#
# After finishing this lab, submit the `lab-9.ipynb` file on Canvas.

# %% [markdown]
# ---
#
# **Name:** *[Your name here]*
# **ID:** *[Your netID here]*
#
# ---

# %% [markdown]
# ### Sum To
#
# #### Part 1
#
# *Adapted from Cornell's CS 1110 (Spring 2025) materials*
#
# Write a function `sum_to` which takes a single argument `n` and returns the value of all of the integers from 1 to `n` (including `n`). Write this function using a for loop.
#
# Include 3-4 tests of your function's behavior, written using whatever technique you want.

# %%
def sum_to(n):
    pass # Replace this statement with your code

# %%
# Write your tests here

# %% [markdown]
# #### Part 2
#
# *Adapted from Cornell's CS 1110 (Spring 2025) materials*
#
# Write a function `sum_to_recursive` that does the exact same thing as `sum_to` but is recursive.
#
# Again, write 3-4 tests for this function – they can be exactly the same as those you used for `sum_to`!

# %%
def sum_to_recursive(n):
    pass # Replace this statement with your code

# %%
# Write your tests here

# %% [markdown]
# ### Countdown (Any Way!)
#
# *Designed with Claude Opus 4.8*
#
# #### Part 1
#
# In this set of GRQs (07/08), you fixed a function called `countdown_by_two`. Now, we'll write a more generalized version of the function called `countdown`, which takes in two arguments – `n`, the number to count down from, and `step`, the number to count down by – and returns a string counting down from n by step each time, ending with `"Blastoff!"`.
#
# For example, `countdown(10, 2)` should return `"10 8 6 4 2 Blastoff!"`.
#
# *Hint*: Think very carefully about what your base case should be!

# %%
def countdown(n, step):
    pass # Replace this statement with your code

# %% [markdown]
# #### Part 2
#
# Write 3 tests for your new `countdown` function, including one where `n` is not perfectly divisible by `step`.

# %%
# Write your tests here

# %% [markdown]
# #### Part 3
#
# What conditions must `n` and `step` values meet for your `countdown` function to work as intended?
#
# First, describe these conditions in one to two sentences. Then, adjust your `countdown` function so that it ensures these conditions are met.

# %% [markdown]
# ---
#
# *[Describe the conditions here]*
#
# ---

# %%
# Write your edited countdown function here

# %% [markdown]
# ### Count Vowels
#
# *Designed with Claude Opus 4.8*
#
# #### Part 1
#
# Write a recursive function called `count_vowels` which takes one string argument, `s`, and returns the number of vowels (`aeiou`) in `s`. Note that this function must be written recursively!
#
# *Hint*: Think about how you might split a string into its first character and the rest of the string.

# %%
def count_vowels(s):
    pass # Replace this statement with your code

# %% [markdown]
# #### Part 2
#
# Write 3 tests for your `count_vowels` function. Remember to consider edge cases!

# %%
# Write your tests here

# %% [markdown]
# ### Recursive Sum
#
# *Designed with Claude Opus 4.8*
#
# #### Part 1
#
# Imagine we want to write a function called `recursive_sum`. The function takes in an argument, `l`, which contains as elements either integers or nested lists which follow the same rule, and returns the sum of all values at any level of the list.
#
# For example, passing the input `[1, [2, 3], [4, [5, 6]]]` would result in a return value of 21.
#
# Describe *in detail* how you would implement this recursive function, including specifying the base and recursive cases.

# %% [markdown]
# ---
#
# *[Write your description here]*
#
# ---

# %% [markdown]
# #### Part 2
#
# Think of 3 tests you might run for the `recursive_sum` function. Since the function doesn't exist yet, we'll just write these tests as markdown.
#
# One test, using the case described above, could be `assert recursive_sum([1, [2, 3], [4, [5, 6]]]) == 21`.

# %% [markdown]
# ---
#
# *[Write your first test here]*
#
# ---

# %% [markdown]
# ---
#
# *[Write your second test here]*
#
# ---

# %% [markdown]
# ---
#
# *[Write your third test here]*
#
# ---

# %% [markdown]
# #### Part 3
#
# Ask the AI chatbot of your choice to write your `recursive_sum` function, using the detailed description you wrote above. Paste the function in the code block below and then use the tests you designed for Part 2 to verify that it works as intended.

# %% [markdown]
# ---
#
# *[Name your chatbot and paste all interactions here – prompts and responses]*
#
# ---

# %%
# Paste your function here

# %%
assert recursive_sum([1, [2, 3], [4, [5, 6]]]) == 21

# Write your tests here
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 assert recursive_sum([1, [2, 3], [4, [5, 6]]]) == 21
#       2
#       3 # Write your tests here
#
# NameError: name 'recursive_sum' is not defined

# %% [markdown]
# #### Part 4
#
# Now, in a new chat, ask the AI chatbot to write your `recursive_sum` function without the detailed description you wrote for Part 1. You can modify the description of the function I wrote in Part 1.
#
# Paste this version of `recursive_sum` below. Then, compare the two generated functions in several sentences. Is there anything different about them, or did the chatbot produce the exact same code? What do you think would happen with these two methods of prompting for increasingly complex code? What are the advantages and disadvantages of either?

# %% [markdown]
# ---
#
# *[Name your chatbot and paste all interactions here – prompts and responses]*
#
# ---

# %%
# Paste the new recursive_sum function here

# %% [markdown]
# ---
#
# *[Write your analysis here]*
#
# ---
