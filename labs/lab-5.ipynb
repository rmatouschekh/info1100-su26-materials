# %% [markdown]
# ## Lab 5: Conditionals
#
# ***due Wednesday 07/01 at 11:30am (EST)***
#
# After finishing this lab, submit the `lab-5.ipynb` file on Canvas.

# %% [markdown]
# ---
#
# **Name:** *[Your name here]*
# **ID:** *[Your netID here]*
#
# ---

# %% [markdown]
# ### Analyzing Data with Conditionals
#
# *Adapted from "Introduction to Cultural Analytics & Python" by Melanie Walsh*
#
# We'll consider data drawn from Anelise Shrout’s Bellevue Almshouse Dataset. Melanie Walsh introduces the dataset by saying:
#
# >The Bellevue Almshouse Dataset includes information about Irish-born immigrants who were admitted to the almshouse in the 1840s.
# >
# >The Bellevue Almshouse was part of New York City’s public health system, a place where poor, sick, homeless, and otherwise marginalized people were sent — sometimes voluntarily and sometimes forcibly. Devastated by widespread famine in Ireland, many Irish people fled their homes for New York City in the 1840s, and many of them ended up in the Bellevue Almshouse. This dataset was transcribed from the almshouse’s own admissions records.
# >
# >We’re using the Bellevue Almshouse Dataset to practice `if`, `elif`, and `else` statements because we want to think deeply about the consequences of reducing human life to data and evaluating “Truth” in Pythonic terms even at this early stage in our Python journey.
# >
# >As Shrout argues in her essay “(Re)Humanizing Data: Digitally Navigating the Bellevue Almshouse,” “Nineteenth-century immigration data was produced with the express purpose of reducing people to bodies; bodies to easily quantifiable aspects; and assigning value to those aspects which proved that the marginalized people to who they belonged were worth less than their elite counterparts.”
# >
# >As you complete the exercises below, reflect about the categories that these Irish immigrants were slotted into by the government. For example, the so-called “disease” that many of the people in this dataset exhibited — the reason they were admitted to the Almshouse in the first place — is “recent emigrant.” What does this uncomfortable fact tell us about data more broadly? What should we make of the fact that Python, as a programming language, doesn’t understand the meaning or historical context of this data?
#
# In the `lab-files` subfolder there's a file called `bellevue_almshouse_modified.csv` which contains this entire dataset. Feel free to explore the data more closely. However, for this assignment we've taken subsets of the data and stored the information in variables, then asked you to write conditionals that analyze that data. While these conditionals may seem overly simple – you can, after all, already see the what the data is – you'll learn techniques later that allow you to use this 'conditional-writing' skill in more complex scenarios!

# %%
# Let's define some relevant variable values

person1_name = 'Mary Gallagher'
person1_age = 28
person1_disease = 'recent emigrant'
person1_profession = 'married'
person1_gender = 'w'
person1_child_status = 'Child Alana 10 days'

person2_name = 'Anthony Clark'
person2_age = 60
person2_disease = 'recent emigrant'
person2_profession = 'laborer'
person2_gender = 'm'
person2_child_status = 'Charles Riley afed 10 days'

person3_name = 'Margaret Farrell'
person3_age = 30
person3_disease = 'recent emigrant'
person3_profession = 'widow'
person3_gender = 'w'
person3_child_status = ''

# %% [markdown]
# #### Part 1
#
# Write an `if` statement that reports whether `person1_age` is less than 30 years old.

# %%
# Write your code here
    print('Person is less than 30 years old.')

# %% [markdown]
# #### Part 2
#
# Write an `if` statement that reports whether `person1_profession` is "married."

# %%
# Write your code here
    print('Person is married.')

# %% [markdown]
# #### Part 3
#
# Write an `if` statement that reports whether `person1_age` is less than 30 years old *and* `person1_profession` is "married."

# %%
# Write your code here
    print('Person is less than 30 years old and married.')

# %% [markdown]
# #### Part 4
#
# Combine an `if` statement with `elif` and `else` statements that will report whether `person2_age` is less than 30 years old, exactly 30 years old, or more than 30 years old.

# %%
# Write your code here
    print('Person is less than 30 years old.')
# Write your code here
    print('Person is exactly 30 years old.')
# Write your code here
    print('Person is more than 30 years old.')

# %% [markdown]
# #### Part 5
#
# Write an `if` statement that will report whether `person1_child_status` includes children.

# %%
# Write your code here
    print('Person has children.')

# %% [markdown]
# #### Part 6
#
# Write a conditional that will report whether `person1_profession` is "married," "laborer," "widow," or "unknown profession." Reassign the value of `person1_profession` to each of the following values in turn to check that your conditional statement is working: "married," "laborer," "widow," or "unknown profession."

# %%
person1_profession = "married"

# %%
# Write your code here
    print('Person is married.')
# Write your code here
    print('Person is a laborer.')
# Write your code here
    print('Person is a widow.')
# Write your code here
    print('Person has unknown profession.')

# %% [markdown]
# #### Part 7
#
# Some of the Irish immigrants’ names have question marks after them. Let’s clean up some of the data and remove the question marks.
#
# You can use the Python keyword `in` to test whether a string appears within another string. Print `person4_name` with the question mark and parentheses removed.
#
# *Hint*: Remember the string functions that you found for Question 3 of the latest set of GRQs? Look through those for help!

# %%
person4_name = 'John Sanin(?)'

# %%
if "(?)" in person4_name:
    # Write your code here

# %% [markdown]
# #### Part 8
#
# *Designed with Claude Opus 4.8*
#
# Write a series of conditionals that determines what "decade" of age `person2_age` is in (e.g. their 20s, 30s, 40s, etc). Print `"Person is in their –"`. This code would work with any age, not just that stored in `person2_age`.
#
# *Hint*: Think about how you might use integer division.

# %%
# Write your code here

# %% [markdown]
# #### Part 9
#
# *Designed with Claude Opus 4.8*
#
# Write a conditional that prints `"Needs review"` if any of the following is true for `person1` and `"Looks good"` otherwise:
# - name contains a question mark
# - recorded age is 120 or older or less than 0
# - their `child_status` is an empty string

# %%
# Write your code here

# %% [markdown]
# #### Part 10
#
# In a few sentences, discuss the following dilemma. What happens when we reduce individuals to pieces of data? What is the impact of using Python or similar computational tools, that don't understand historical meaning or human context, to study people? How can we be sure to preserve the historical context and human meaning behind data when we are working with Python? Finally, what impact may the introduction of AI tools into our computational workflows have?
#
# *Note*: This is a very general set of questions to ask! There is no correct answer here; I just want you to start thinking about these considerations.

# %% [markdown]
# ---
#
# *[Write your answer here]*
#
# ---
