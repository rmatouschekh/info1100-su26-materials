# %% [markdown]
# ## Lab 13: Classes + Objects (Part 1)
#
# ***due Friday 07/17 at 11:30am (EST)***
#
# After finishing this lab, submit the `lab-13.ipynb` file on Canvas.

# %% [markdown]
# ---
#
# **Name:** *[Your name here]*
# **ID:** *[Your netID here]*
#
# ---

# %% [markdown]
# ### Who's in Class?
#
# Throughout this lab, we're going to work on creating a `Student` class and associated functions.

# %% [markdown]
# #### Part 1
#
# In today's reading, we learned about class attributes. What are some attributes we may want a `Student` class to have? Why? How may this vary based on *why* we're building a `Student` class?

# %% [markdown]
# ---
#
# *[Write your answer here]*
#
# ---

# %% [markdown]
# #### Part 2
#
# Let's say this `Student` class is meant to represent members of a course. Some relevant information might therefore be: their name, their level (first-year, junior, etc), and their current grade.
#
# Define the `Student` class and then write a function called `make_student` which creates a `Student` object, assigns name, level, and grade attributes to the new object, and then returns it. Note that there are some choices you can make on how to represent these attributes (do you store the name as a single string, or split up first and last names? should level be a string, or do you want to represent it as an integer?). Then, describe your choices in two to three sentences.
#
# *Note*: You can look at the `make_time` function in Section 14.3 of the reading as an example of what this function should look like!

# %%
# Write your Student class here

# %%
# Write your make_student function here

# %% [markdown]
# ---
#
# *[Write your description here]*
#
# ---

# %% [markdown]
# #### Part 3
#
# Adapt your `make_student` function from above to write checks using `assert` for each parameter. Think carefully about what you need to check – it might not be enough to check that it's the right type. Write 3-4 tests for your new `make_student` function.

# %%
# Write your *new* make_student function here

# %%
# Write your tests here

# %% [markdown]
# #### Part 4
#
# Write a function called `change_grade` which takes in a `Student` object, a new grade, and a weight. Then, update the grade attribute of the `Student` so that it takes into account the new grade, which is weighted according to the weight argument (the updated grade should be `(1 - weight) * old_grade + weight * new_grade`). Add 3-4 tests for your new function.

# %%
# Write your function here

# %%
# Write your tests here

# %% [markdown]
# #### Part 5
#
# Now, ask the AI chatbot of your choice to write a `Student` class. Then, let's think about what it outputs. What design choices does it make when given no instruction? How do those choices compare to the ones you've made? What do you understand of its output, and what's new?

# %% [markdown]
# ---
#
# *[Name your chatbot and paste all interactions here – prompts and responses]*
#
# ---

# %%
# Paste the chatbot's Student class here

# %% [markdown]
# ---
#
# *[Write your answer here]*
#
# ---
