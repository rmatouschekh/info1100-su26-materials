# %% [markdown]
# ## GRQs: Dictionaries
# ***due Thursday 07/09 at 11:30am (EST)***
#
# Answer each of the following questions with either the requested code or a multi-sentence written response. This assignment will be scored on completion.

# %% [markdown]
# ---
#
# **Name:** *[Your name here]*
# **ID:** *[Your netID here]*
#
# ---

# %% [markdown]
# ### Question 1
#
# The reading briefly mentions a data structure called a hash table and the idea of hashing a value. While we won't discuss it much in this class, hashing is a critical element of writing efficient programs.
#
# Ask an AI chatbot of your choice to teach you more about hash tables and hashing. Keep the exchange going until you feel like you have a decent understanding of the topic, although you don't need to understand the details of how they work. Then, synthesize what you learned into a couple of sentences that you think would help a student with the same programming knowledge as you learn about hashing.

# %% [markdown]
# ---
#
# *[Name your chatbot and paste all interactions here – prompts and responses]*
#
# ---

# %% [markdown]
# ---
#
# *[Write your description of hashing here]*
#
# ---

# %% [markdown]
# ### Question 2
# *Adapted from Exercise 10.11.3 in "Think Python" by Allen B. Downey*
#
# Write a function named `has_duplicates` that takes a sequence – like a list or string – as a parameter and returns `True` if there is any element that appears in the sequence more than once. Then, write at least 3 function tests to confirm that your function works as intended.

# %%
# Write your function here

# %%
# Write your tests here

# %% [markdown]
# ### Question 3
#
# Consider when and how you might want to use dictionaries when writing your own code. Think especially about how they might be used for data analysis.
#
# Describe some scenarios in which you'd need dictionaries. What is your code doing and why are dictionaries necessary? What other programming elements, data structures, or functions may you need in these scenarios? Is there anything you'd need to know that we haven't learned already?

# %% [markdown]
# ---
#
# *[Write your answer here]*
#
# ---

# %% [markdown]
# ### Question 4
# *Adapted from CS 1110 materials by W. White and Leah Pearlmutter*
#
# Imagine a dictionary that maps student ids to their course grades. An example of such a dictionary is given in the code block below.
#
# Write a function called `letter_grades` which takes such a dictionary as an argument and returns a dictionary mapping student ids to the equivalent letter grades. The cut-off is 90 for an A, 80 for a B, 70 for a C, 60 for a D. Anything below 60 is an F.
#
# Write 2-3 tests checking the performance of your function. The example given below does not count as a test.
#
# *Hint*: You will need a dictionary that acts as an accumulator. Start with result = {}. Then add to this dictionary.

# %%
example_dict = {'rmh327' : 55, 'abc3' : 90, 'jms45': 86}
# letter_grades(example_dict) should return {'rmh327' : 'F', 'abc3' : 'A', 'jms45': 'B'}

# %%
# Write your function here.

# %%
# Write your tests here.
