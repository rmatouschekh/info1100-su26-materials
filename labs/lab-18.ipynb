# %% [markdown]
# ## Lab 18: Data Visualization (Principles)
#
# ***due Thursday 07/30 at 11:30am (EST)***
#
# After finishing this lab, submit the `lab-18.ipynb` file on Canvas.

# %% [markdown]
# ### Deep Dive
#
# The reading for today introduced a lot of cool topics that you can dive a lot farther into. Choose one of the following topics:
# - Edward Tufte's work on visualization
# - perceiving color and creating good color palettes
# - preattentive search
# - Gestalt rules
# - "good" vs. "bad" visualization types
# - data channels
#
# Then, find a number of *trustworthy* sources that help you learn more about that topic. You can use AI chatbots to *find* those sources, but a chatbot does not constitute a trustworthy source in and of itself.
#
# Then, synthesize what you learned into a 200-300 word overview of the topic. Cite your sources as appropriate. Think not only about *what* material you should cover, but also *how* you synthesize it. Try to make your writing clear, concise, and academic.

# %% [markdown]
# ---
#
# *[If used, name your chatbot and paste all interactions here – prompts and responses]*
#
# ---

# %% [markdown]
# ---
#
# *[List your sources here; you may cite in whatever format is most comfortable.]*
#
# ---

# %% [markdown]
# ---
#
# *[Write your answer here]*
#
# ---
