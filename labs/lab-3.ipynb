# %% [markdown]
# ## Lab 3: Variables + Statements
#
# ***due Thursday 06/25 at 11:30am (EST)***
#
# After finishing this lab, submit the `lab-3.ipynb` file on Canvas.

# %% [markdown]
# ---
#
# **Name:** *[Your name here]*
# **ID:** *[Your netID here]*
#
# ---

# %% [markdown]
# ### Make Me Understand(able)
#
# Check out the Python program below. The code itself isn't too complicated, but it's pretty hard to figure out what's going on – in part because the variable names don't give you any extra information!
#
# Look through the code until you think you understand exactly what's going on. Write a short description of what the code is doing and then edit the code directly in the code block to add variable names that make sense.
#
# *Note*: This program is not written as concisely or coherently as it would normally be, but gives you the opportunity to think carefully about the impact of code structure and variable names on writing code.

# %%
# Code written by GPT-5.5

a = 87
b = 92
c = 78

d = 0.40
e = 0.20
f = 0.40

g = a * d
h = b * e
i = c * f

j = g + h + i

k = "Final grade:"
print(k, round(j, 1))
# Out:
# Final grade: 84.4

# %% [markdown]
# ---
#
# *[Write your description here]*
#
# ---

# %% [markdown]
# ### Who Am I?
#
# #### Part 1
#
# Another way to think about the impact of clearly written code is by trying to parse code that may contain elements you haven't learned yet.
#
# Explore the code in the block below. You can try changing variable values, but focus especially on the variable names and other *keywords* that might give you hints about what's happening. Then, write a brief description of what you think the code does in the designated box below; don't worry if you don't get it right!

# %%
# Adapted from code written by GPT-5.5

def calculate_tip(meal_cost):
    tip_rate = 0.20
    return meal_cost * tip_rate

restaurant_bills = [25, 52, 34, 63]

i = 1
for bill in restaurant_bills:
    tip = calculate_tip(bill)
    total_cost = bill + tip

    print("Meal " + str(i) + " cost is " + str(total_cost) + " dollars.")
    i += 1
# Out:
# Meal 1 cost is 30.0 dollars.
# Meal 2 cost is 62.4 dollars.
# Meal 3 cost is 40.8 dollars.
# Meal 4 cost is 75.6 dollars.

# %% [markdown]
# ---
#
# *[Write your description of the code here]*
#
# ---

# %% [markdown]
# #### Part 2
#
# Let's double check your work! Ask the AI chatbot of your choice what the code does. Then, reflect on the results. Does its explanation make sense to you? How close was it to your guess?

# %% [markdown]
# ---
#
# *[Name your chatbot and paste all interactions here – prompts and responses]*
#
# ---

# %% [markdown]
# ---
#
# *[Write your reflection here]*
#
# ---
