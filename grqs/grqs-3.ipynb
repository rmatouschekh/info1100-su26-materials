# %% [markdown]
# ## GRQs: Strings
# ***due Thursday 06/25 at 11:30am (EST)***
#
# Answer each of the following questions with either the requested code or a multi-sentence written response. This assignment will be scored on completion.

# %% [markdown]
# ---
#
# **Name:** *[Your name here]*
# **ID:** *[Your netID here]*
#
# ---

# %% [markdown]
# ### Question 1
#
# Consider what real-world data we might represent as strings in a program. List 2-3 examples.

# %% [markdown]
# ---
#
# *[Write your answer here]*
#
# ---

# %% [markdown]
# ### Question 2
#
# This chapter described how to slice strings. For each of the strings below, fill in the brackets (`[]`) with the values that will select the substring `info`. If you've gotten the right indices, each statement should print `info`. However... no two sets of indices should be the same! You'll have to get creative.

# %%
slice_str_1 = "information"

# Replace : with your slice
print(slice_str_1[:])
# Out:
# information

# %%
slice_str_2 = "misinform"

# Replace : with your slice
print(slice_str_2[:])
# Out:
# misinform

# %%
slice_str_3 = "uninformed"

# Replace : with your slice
print(slice_str_3[:])
# Out:
# uninformed

# %%
slice_str_4 = "info"

# Replace : with your slice
print(slice_str_4[:])
# Out:
# info

# %%
slice_str_5 = "infomercial"

# Replace : with your slice
print(slice_str_5[:])
# Out:
# infomercial

# %% [markdown]
# ### Question 3
#
# Ask the AI chatbot of your choice to provide you with all of the Python string methods. There's a lot of them! Some might make use of concepts we haven't learned yet. Using the chatbot, try to determine what **5** methods do, and use them on the string defined below!
#
# *Note:* You can change the value of the string in order to use your methods if needed.

# %% [markdown]
# ---
#
# *[Name your chatbot and paste all interactions here – prompts and responses]*
#
# ---

# %%
test_string = "this is your test string!"

# %%
# Write your first function here

# %%
# Write your second function here

# %%
# Write your third function here

# %%
# Write your fourth function here

# %%
# Write your fifth function here
