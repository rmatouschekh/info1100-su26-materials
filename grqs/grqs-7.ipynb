# %% [markdown]
# ## GRQs: For + While Loops
# ***due Tuesday 07/07 at 11:30am (EST)***
#
# Answer each of the following questions with either the requested code or a multi-sentence written response. This assignment will be scored on completion.

# %% [markdown]
# ---
#
# **Name:** *[Your name here]*
# **ID:** *[Your netID here]*
#
# ---

# %% [markdown]
# ### Question 1.1
# *Adapted from Exercise 7.9.2 in "Think Python" by Allen B. Downey*
#
# Write a function named `uses_none` that takes a word and a string of forbidden letters, and returns `True` if the word does not use any of the forbidden letters.
#
# Fill in the function below.

# %%
def uses_none(word, forbidden):
    # Write your function here
    pass

# %% [markdown]
# ### Question 1.2
# *Adapted from Exercise 7.9.3 in "Think Python" by Allen B. Downey*
#
# Write a function called `uses_only` that takes a word and a string of letters, and that returns `True` if the word contains only letters in the string.
#
# Fill in the function below.

# %%
def uses_only(word, available):
    # Write your function here
    pass

# %% [markdown]
# ### Question 1.3
#
# You may have noticed that I usually provide test statements to help you check whether your code is working as intended. Learning how to write simple tests like this is a very valuable exercise. In many software engineering settings, you would be required to write formal test suites for code you developed. But even when you're coding more casually, it's super important to make sure you double-check that your code is behaving as expected; this is even more important when an LLM may have written parts of your code.
#
# To that end, your task is to design three tests each for the functions you wrote for Questions 2.1 and 2.2. Format them as print statements that check whether function calls return the expected values (as those I provide for Question 3 below). Try to consider what edge cases or unusual situations need to be covered in each function, and test those!

# %%
# Your tests for uses_none

# %%
# Your tests for uses_only

# %% [markdown]
# ### Question 2
#
# One of the most basic ways of encrypting text is called the Caesar cipher, which you can read more about [here](https://en.wikipedia.org/wiki/Caesar_cipher). Basically, a Caesar cipher takes in the string to be encrypted and returns the same string with each letter shifted `n` letters forward in the alphabet. So the word `caesar` encrypted with an `n` of 3 would be `fdhvdu`.
#
# Your job is to get the AI chatbot of your choice to write a function called `encrypt` which takes in two arguments – the string to encrypt and the value `n` – and returns the encrypted string. The function the chatbot designs *must* use a for or while loop. Writing this code will require some functions that you haven't learned yet; **continue querying the chatbot until you understand each part of the code**.
#
# In the code block below, include the function the chatbot gave you with comments explaining *each* line of code. If the function works properly, all of the print statements should print `True`. Include the full conversation you had with the chatbot where prompted.
#
# *Hint:* The last print function below will only work if you get your code to handle a special case. To figure it out, consider what happens when you try to shift `y` with an `n` of 3.

# %%
def encrypt(text, n):
    # Write your function here
    pass

# %%
# Tests for the encrypt() function
print(encrypt("caesar", 3) == "fdhvdu")
print(encrypt("Hello world", 1) == "Ifmmp xpsme")
print(encrypt("xylophone", 7) == "efsvwovul")
# Out:
# True
# True
# True

# %% [markdown]
# ---
#
# *[Name your chatbot and paste all interactions here – prompts and responses]*
#
# ---

# %% [markdown]
# ### Question 3
#
# *Designed with Claude Sonnet 4.6*
#
# Write a function called `first_vowel` which takes a single string and returns the first vowel in the string. If the string contains no vowels, the function should return `None`. You can assume that the argument `text` will always be lowercase.
#
# You should use a `while` loop (not a `for` loop!) in the function.

# %%
def first_vowel(text):
    pass # Replace this statement with your code

# %%
print(first_vowel("rhythm") == None)
print(first_vowel("hello") == "e")
print(first_vowel("aeiou") == "a")
# Out:
# True
# False
# False
