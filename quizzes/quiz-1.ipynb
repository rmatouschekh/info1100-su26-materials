# %% [markdown]
# ## Quiz 1
#
# ***Friday 06/26***
#
# Topics: Types + Expressions, Variables + Statements, Strings

# %% [markdown]
# ### Concept Questions
#
# 1. Explain the difference between float and integer division. Give an example where they would result in different outputs.
# 2. Explain the difference between values and expressions.
# 3. Explain what a type is. List 3 and give examples of each.
# 4. Explain the difference between formal and natural languages.
# 5. Explain what variables are and why we use them.
# 6. Explain why variable names can be important. Give an example of a scenario where a variable name may make a difference.
# 7. Explain the difference between expressions and statements.
# 8. Explain what an argument is. Give an example of when one would be used.
# 9. Explain what string immutability is and how it affects our programs.
# 10. Explain the difference between semantic and syntactic errors.

# %% [markdown]
# ### Explain this Code

# %% [markdown]
# 1. Explain what each line of the code does. Then, tell me what the `slice_int` variable will be equal to after the code runs.
#
#     If you think the code would throw an error, identify it and explain what you think the code is *trying* to do.
#
#     ```python
#     example_str = "There are 152 apples in the store."
#     str_slice = example_str[10:13]
#     slice_int = int(str_slice)
#     ```

# %% [markdown]
# 2. Explain what each line of the code does. Then, tell me what each print statement will print.
#
#     If you think the code would throw an error, identify it and explain what you think the code is *trying* to do.
#
#     ```python
#     important = 2 * (5 + 4)
#     split_important = important / 3
#     print(split_important)
#     print(type(split_important))
#     ```

# %% [markdown]
# 3. Explain what each line of the code does. Then, tell me what the print statement prints.
#
#     If you think the code would throw an error, identify it and explain what you think the code is *trying* to do.
#
#     ```python
#     cheer = "hey, ho!" * 2 + "let's go!" + "hey, ho!" * 2
#     change = cheer.find("go!")
#     print(cheer[change:change+3].upper())
#     ```

# %% [markdown]
# 4. Explain what each line of code does. Then, tell me what the print statement prints.
#
#     If you think the code would throw an error, identify it and explain what you think the code is *trying* to do.
#
#     ```python
#     num = -47.6
#     num = abs(round(num))
#     print(len(str(num)))
#     ```

# %% [markdown]
# 5. Explain what each line of the code does. Then, tell me what the `greeting` variable will be equal to after the code runs.
#
#     If you think the code would throw an error, identify it and explain what you think the code is *trying* to do.
#
#     ```python
#     name = "Mike"
#     greeting = "Hey " + name + "!"
#     greeting[len("Hey "):len("Hey ") + len(name)] = "John"
#     ```
