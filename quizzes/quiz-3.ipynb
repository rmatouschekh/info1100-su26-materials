# %% [markdown]
# ## Quiz 3
#
# ***Friday 07/10***
#
# Topics: For + While Loops, Recursion, Dictionaries

# %% [markdown]
# ### Concept Questions

# %% [markdown]
# 1. Explain the difference between for and while loops. Include: the basic structure of both kinds of loop, how both kinds of loop execute, and scenarios in which you would prefer a for over a while loop and vice versa.
# 2. Explain what the purpose of recursion is. Then: name the two main parts of recursive functions, what the purpose of each is, and what would happen if either case was removed.
# 3. Explain the difference between dictionaries and lists (think mapping). Include: the syntax for accessing values in both, what can be used to access values in both, and what values can be stored in both.

# %% [markdown]
# ### Explain this Code
# *Example code partially Claude generated*

# %% [markdown]
# 1. Explain what each line of the code does. Then, tell me what the print statement will print.
#
#     If you think the code would throw an error, identify it and explain what you think the code is *trying* to do.
#
#     ```python
#     def helper(n):
#         if n < 10:
#             return [n]
#         return helper(n // 10) + [n % 10]
#
#     def mystery(lst):
#         d = {}
#         i = 0
#         while i < len(lst):
#             d[lst[i]] = len(helper(lst[i]))
#             i += 1
#         return d
#
#     print(mystery([5, 42, 178]))
#     ```

# %% [markdown]
# 2. Explain what each line of the code does. Then, tell me what the print statement will print.
#
#     If you think the code would throw an error, identify it and explain what you think the code is *trying* to do.
#
#     ```python
#     def helper(l):
#         if len(l) == 0:
#             return 0
#         return l[0] + helper(l[1:])
#
#     def mystery(lst):
#         d = {}
#         for w in lst:
#             d[w] = len(w)
#         return helper(list(d.values()))
#
#     print(mystery(["hi", "cat", "hi", "dog"]))
#     ```

# %% [markdown]
# 3. Explain what each line of the code does. Then, tell me what the print statement will print.
#
#     If you think the code would throw an error, identify it and explain what you think the code is *trying* to do.
#
#     ```python
#     def helper(l):
#         if len(l) == 0:
#             return 0
#         return l[0] + helper(l[1:])
#
#     def mystery(s, d):
#         lst = []
#         for ch in s:
#             if ch in d:
#                 lst.append(d[ch])
#         return helper(lst)
#
#     print(mystery("cabbage", {"a": 1, "b": 3, "c": 5}))
#     ```
