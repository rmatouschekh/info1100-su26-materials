# %% [markdown]
# ## GRQs: Variables + Statements
# ***due Wednesday 06/24 at 11:30am (EST)***
#
# Answer each of the following questions with either the requested code or a multi-sentence written response. This assignment will be scored on completion.

# %% [markdown]
# ---
#
# **Name:** Rebecca Hicke.
# **ID:** *[Your netID here]*
#
# ---

# %% [markdown]
# ### Question 1
#
# Come up with five different illegal variable names, and describe why each is illegal. Each variable name should be illegal for a different reason!

# %% [markdown]
# ---
#
# *[Write your answer here]*
#
# ---

# %% [markdown]
# ### Question 2.1
# *Adapted from the CS 111.01 course materials by Tanya Amert*
#
# Choosing variable names can be very important for writing code that is easy for both you and others to parse. The code excerpt below has very terrible variable names! Consider what the code does, and then rename each variable to something that makes sense.

# %%
a = "Bob"
b = "Jeremy"
c = "Smith"
d = 21

print("Hello there!")
print("Have a great day, " + a + " " + b + " " + c)
print("You are at least", d*365, "days old.")
# Out:
# Hello there!
# Have a great day, Bob Jeremy Smith
# You are at least 7665 days old.

# %% [markdown]
# ### Question 2.2
#
# Ask the AI chatbot of your choice to give the code more semantically meaningful variable names. What did it choose? Was it the same or different from what you selected? Is one or the other better?

# %% [markdown]
# ---
#
# *[Name your chatbot and paste all interactions here – prompts and responses]*
#
# ---

# %% [markdown]
# ---
#
# *[Write your analysis here]*
#
# ---

# %% [markdown]
# ### Question 3
#
# Comment the code below. Try to create comments that you think would help someone understand what's happening in the code, even if they don't know any Python!

# %%
import math

r = 10
area = math.pi * (r ** 2)

print(area)
# Out:
# 314.1592653589793

# %% [markdown]
# ### Question 4
#
# Ask a the AI chatbot of your choice to produce two examples each of syntax, runtime, and semantic errors. Are the examples correct, according to the definitions in the reading? Can you understand what causes each error? If not, can you get the chatbot to effectively explain them to you?

# %% [markdown]
# ---
#
# *[Name your chatbot and paste all interactions here – prompts and responses]*
#
# ---

# %% [markdown]
# ---
#
# *[Write your analysis here]*
#
# ---
