# %% [markdown]
# ## GRQs: Conditionals
# ***due Tuesday 06/30 at 11:30am (EST)***
#
# Answer each of the following questions with either the requested code or a multi-sentence written response. This assignment will be scored on completion.

# %% [markdown]
# ---
#
# **Name:** *[Your name here]*
# **ID:** *[Your netID here]*
#
# ---

# %% [markdown]
# ### Question 1.1
# *Adapted from Exercise 5.14.1 in "Think Python" by Allen B. Downey*
#
# The boolean operator XOR, the exclusive or, returns `True` only when the inputs are different. The truth table for XOR is:
#
#
# | p | q | p XOR q |
# | -------- | -------- | -------- |
# | True | True | False |
# | True | False | True |
# | False | True | True |
# | False | False | False |
#
# Python does not have a built in XOR operator. Write your own version of the XOR operator using only the built-in `and`, `or`, and `not` operators.

# %% [markdown]
# ---
#
# *[Write your answer here]*
#
# ---

# %% [markdown]
# ### Question 1.2
#
# Now, ask the AI chatbot of your choice how you would instantiate the XOR operator in Python. It will likely offer you a number of options. How do they compare to the XOR you wrote? Are they all equivalent? Which do you think is the easiest to understand? Which is the most useful?
#
# If you don't understand one of the options proposed by the chatbot, try to figure out as much of it as you can by further querying the chatbot. Include all further prompts and answers in the appropriate section below!

# %% [markdown]
# ---
#
# *[Name your chatbot and paste all interactions here – prompts and responses]*
#
# ---

# %% [markdown]
# ---
#
# *[Write your answer here]*
#
# ---

# %% [markdown]
# ### Question 2
#
# Consider the code below. It looks pretty messy! Using the additional code block below, try to rewrite the code so it *doesn't* use any nested conditionals. It's a good idea to double check that the output of the original code and your re-write are the same for various values of `x`.

# %%
x = 36

if x%2 == 0:
    if x%3 == 0:
        print("I'm divisible by 2, 3, and 6!")
    else:
        print("I'm divisible by 2!")
elif x%3 == 0:
    print("I'm divisible by 3!")
else:
    print("I'm not divisible by 2, 3, or 6 :(.")
# Out:
# I'm divisible by 2, 3, and 6!

# %%
# Write your version of the code here

# %% [markdown]
# ### Question 3
# *Adapted from Exercise 5.14.3 in "Think Python" by Allen B. Downey*
#
# If you are given three sticks, you may or may not be able to arrange them in a triangle. For example, if one of the sticks is 12 inches long and the other two are one inch long, you will not be able to get the short sticks to meet in the middle. For any three lengths, there is a test to see if it is possible to form a triangle:
#
# >If any of the three lengths is greater than the sum of the other two, then you cannot form a triangle. Otherwise, you can. (If the sum of two lengths equals the third, they form what is called a “degenerate” triangle.)
#
# Using the variables defined below, write a conditional statement that uses the three integers and prints either “Yes” or “No”, depending on whether you can or cannot form a triangle from sticks with the given lengths.
#
# *Hint:* Use a chained conditional. Test out different values of a, b, and c.

# %%
a = 12
b = 1
c = 1

# Write your code here
