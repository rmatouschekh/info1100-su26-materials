# %% [markdown]
# ## Lab 19: Data Visualization (in Python)
#
# ***due Wednesday 07/31 at 11:30am (EST)***
#
# After finishing this lab, submit the `lab-19.ipynb` file on Canvas.

# %% [markdown]
# ---
#
# **Name:** *[Your name here]*
# **ID:** *[Your netID here]*
#
# ---

# %%
# Run me before continuing!
# %matplotlib inline

# %% [markdown]
# ### Choose the Lens
#
# We'll be working with the dataset on blood test values for Hepatitis-C patients that we used in Lab 15 again, which I've loaded into the `hcv_data` variable in the code block below.
#
# As a reminder, here is the description of what's in the data from Lab 15:
# > The dataset contains 13 values. The first is an integer label representing the Hepatitis-C status of the individual: 0 (healthy blood donor), 1 (Hepatitis), 2 (Fibrosis), or 3 (Cirrhosis). Some of the blood donors' health status is unknown – for the purposes of this lab, these are grouped in with the other blood donors. The second value in the data set is age (in years) and the third labels binary sex, where 0 is male and 1 is female. The remaining values represent different blood test values: ALB (albumin), ALP (alkaline phosphatase), ALT (alanine transaminase), AST (aspartate aminotransferase), BIL (bilirubin), CHE (cholinesterase), CHOL (cholesterol), CREA (creatinine), GGT (gamma-glutamyl transferase), and PROT (protein).

# %%
import numpy as np

with open("lab-files/hcv_data.npy", "rb") as f:
    hcv_data = np.load(f)

# %% [markdown]
# #### Part 1
#
# This dataset provides a lot of opportunities for examining the relationship between different variables. We looked at some of these relationships in Lab 15, but we've never visualized any of them and we've only ever looked at the relationship between three or more variables in the dataset.
#
# Choose three of the variables in the dataset that you're interested in examining the relationship between. In a few sentences, describe the variables you've picked, why you're interested in their relationship, and a hypothesis about what you may find.

# %% [markdown]
# ---
#
# *[Write your answer here]*
#
# ---

# %% [markdown]
# #### Part 2
#
# Now, let's think about how you may effectively visualize the relationship between the three variables you selected.
#
# Specifically, come up with *five* different ways to visualize the three variables you chose. Include details about what visual channel you will use to encode each variable and the type of visualization you propose (e.g., scatterplot, bar chart, etc). Additionally, describe why you think this visualization is a good fit for studying the data you chose.

# %% [markdown]
# ---
#
# *[Describe your first visualization and your reason for choosing it here]*
#
# ---

# %% [markdown]
# ---
#
# *[Describe your second visualization and your reason for choosing it here]*
#
# ---

# %% [markdown]
# ---
#
# *[Describe your third visualization and your reason for choosing it here]*
#
# ---

# %% [markdown]
# ---
#
# *[Describe your fourth visualization and your reason for choosing it here]*
#
# ---

# %% [markdown]
# ---
#
# *[Describe your fifth visualization and your reason for choosing it here]*
#
# ---

# %% [markdown]
# #### Part 3
#
# Using the AI chatbot of your choice, create each of the five visualizations you described above. You can either prompt the chatbot to create the visualization with placeholder data, and then edit it to use the `hcv_data` variable *or* pass the chatbot the dataset and have it create versions that work directly.
#
# Paste the code that creates each visualization in the designated code blocks below. The visualizations should display inline. If the chatbot's first attempt does not create the visualization you intended, continue prompting the chatbot or edit it yourself until you have the visualization you imagined.
#
# *Note*: Remember from Lab 15 that the data has missing values and you may need to filter the data before plotting.

# %% [markdown]
# ---
#
# *[Name your chatbot and paste all interactions here – prompts and responses]*
#
# ---

# %%
# Paste your code for visualization one here

# %%
# Paste your code for visualization two here

# %%
# Paste your code for visualization three here

# %%
# Paste your code for visualization four here

# %%
# Paste your code for visualization five here

# %% [markdown]
# #### Part 4
#
# Now, consider each of the visualizations that you created above. Write a couple of sentences describing the pros and cons of each visualization – consider both the visualization principles you learned from the *Look at Data* reading and its ability to analyze the specific variables you chose to study.

# %% [markdown]
# ---
#
# *[Analyze your first visualization here]*
#
# ---

# %% [markdown]
# ---
#
# *[Analyze your second visualization here]*
#
# ---

# %% [markdown]
# ---
#
# *[Analyze your third visualization here]*
#
# ---

# %% [markdown]
# ---
#
# *[Analyze your fourth visualization here]*
#
# ---

# %% [markdown]
# ---
#
# *[Analyze your fifth visualization here]*
#
# ---

# %% [markdown]
# #### Part 5
#
# Given your analysis of each proposed visualization in Part 4, choose which visualization you think best represents the relationship between the three variables you chose and then explain why.

# %% [markdown]
# ---
#
# *[Write your answer here]*
#
# ---

# %% [markdown]
# #### Part 6
#
# Usually, we want to make some changes to a visualization, even if we're happy with the basic choices (type of visualization, etc). These can include the size of figure labels or the exact colors you're using. Either independently or using the AI chatbot of your choice, adjust your visualization code until you're happy with the final product.

# %% [markdown]
# ---
#
# *[Name your chatbot and paste all interactions here – prompts and responses]*
#
# ---

# %%
# Paste your final visualization code here

# %% [markdown]
# #### Part 7
#
# Now that you have an effective visualization, let's return to why you were interested in the relationship between these three variables to begin with. In a few sentences, write what we can learn about that relationship from the visualization. Include whether your hypothesis from Part 1 was supported or refuted.

# %% [markdown]
# ---
#
# *[Write your answer here]*
#
# ---
