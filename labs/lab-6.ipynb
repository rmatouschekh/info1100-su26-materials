# %% [markdown]
# ## Lab 6: Functions
#
# ***due Thursday 07/02 at 11:30am (EST)***
#
# After finishing this lab, submit the `lab-6.ipynb` file on Canvas.

# %% [markdown]
# ---
#
# **Name:** *[Your name here]*
# **ID:** *[Your netID here]*
#
# ---

# %% [markdown]
# ### Remove First Vowel
#
# #### Part 1
#
# *Adapted from Cornell's CS 1110 (Spring 2025) materials*
#
# We're going to write a function `remove_first_vowel` that removes the first letter from a string argument `w` if it is a vowel. You can assume `w` contains only lowercase letters.
#
# If the string's first character isn't a vowel, return the string unchanged. The vowels are `'aeiou'`.

# %%
def remove_first_vowel(w):
    pass # Replace this statement with your code

# %% [markdown]
# #### Part 2
#
# *Adapted from Cornell's CS 1110 (Spring 2025) materials*
#
# When writing code, it's very important that we double-check that it's working as intended. Writing functions for sections of code that we'll want to use multiple times can help you ensure that your code works as intended; both because it means you won't be writing the same code multiple times (each time is a new place you can introduce errors!) and because you can easily write tests for your functions.
#
# There are a variety of ways to implement tests for your functions. I gave an example of one way of writing tests in Question 4 of the most recent set of GRQs: writing print statements that confirm that the output of a function given a particular argument(s) is as expected.
#
# Let's test your `remove_first_vowel` function! Write 4 additional tests for your function of the form `print(remove_first_vowel([word]) == [expected output])`. Try to think of special cases that might have weird behavior!

# %%
print(remove_first_vowel("electric") == "lectric")
# Add your tests here
# Out:
# False

# %% [markdown]
# #### Part 3
#
# Ask the AI chatbot of your choice to provide tests for your `remove_first_vowel` function – giving as much information about the function as you want! You can pass the entire function, give it just the name, or give a description of what the function is supposed to do.
#
# Then, reflect on the tests the chatbot produced. Does it catch any cases you didn't? Does it provide tests that you think are "good" or "bad" for any particular reason? Did anything about your prompt, especially how much information you provided about the function, seem to influence what tests were generated?

# %% [markdown]
# ---
#
# *[Name your chatbot and paste all interactions here – prompts and responses]*
#
# ---

# %% [markdown]
# ---
#
# *[Write your reflection here]*
#
# ---
