# %% [markdown]
# ## GRQs: Types + Expressions
# ***due Tuesday 06/23 at 11:30am (EST)***
#
# Answer each of the following questions with either the requested code or a multi-sentence written response. This assignment will be scored on completion.

# %% [markdown]
# ---
#
# **Name:** *[Your name here]*
# **ID:** *[Your netID here]*
#
# ---

# %% [markdown]
# ### Question 1
#
# Much like I did in class, this reading argues that "learning to program means learning a new way to think." Give 2-3 examples from this chapter of ways in which you're being asked to think of familiar concepts in new ways.

# %% [markdown]
# ---
#
# *[Write your answer here]*
#
# ---

# %% [markdown]
# ### Question 2
#
# Write 3 different expressions which result in the string `hello, hello, hello!`

# %%
# Your first expression

# %%
# Your second expression

# %%
# Your third expression

# %% [markdown]
# ### Question 3
#
# Ask the AI chatbot of your choice what the difference between a formal and a natural language is. Include the exact prompt you give below. Then, compare and contrast the answer you get from the chatbot with the one provided in the assigned reading. Do you think the description is more or less helpful than the one in the textbook?

# %% [markdown]
# ---
#
# *[Name your chatbot and paste all interactions here – prompts and responses]*
#
# ---

# %% [markdown]
# ---
#
# *[Write your answer here]*
#
# ---

# %% [markdown]
# ### Question 4
#
# *Designed with Claude Opus 4.8*
#
# Today's reading demonstrated how type names can also be used to convert values from one type to another; for example, `str(56)` would result in the string `"56"`.
#
# The first code block below confirms that the type of the value 42.75 is `float`. In the following two code blocks, convert 42.75 into a) an integer and b) a string. Then, try dividing all three values by 3 using `/ 3` *and* `// 3`.
#
# Then, write a two to three sentence reflection on each experiment. How did the value of 42.75 change in each form? What happened when you tried to divide each version?

# %%
type(42.75)
# Out:
# float

# %%
# Write your integer here

# %%
# Write your string here

# %% [markdown]
# ---
#
# *[Write your answer here]*
#
# ---
