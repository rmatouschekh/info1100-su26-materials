# %% [markdown]
# ## Lab 14: Classes + Objects (Part 2)
#
# ***due Wednesday 07/22 at 11:30am (EST)***
#
# After finishing this lab, submit the `lab-14.ipynb` and `card.py` files on Canvas.

# %% [markdown]
# ---
#
# **Name:** *[Your name here]*
# **ID:** *[Your netID here]*
#
# ---

# %% [markdown]
# ### Playing Cards
#
# *Adapted from Cornell's CS 1110 (Spring 2025) materials*
#
# For today's lab, we'll primarily be writing code in the supplementary file `card.py`. However, this document will still be important for tracking exactly what work you need to get done, and writing reflections!
#
# Today's goal is to write a class representing a `Card` from a deck of standard playing cards. `card.py` has some code already written to help you get started.

# %% [markdown]
# #### Part 1
#
# Each `Card` object has two attributes – `_suit` and `_rank`. Because these are *hidden* attributes, they aren't defined directly under the class heading, like some we've seen. Instead, we'll design `get` and `set` methods for each variable. Briefly, the `get` methods should return the attribute of interest and the `set` methods should set the attribute. Critically, writing `set` methods allows you to make sure that the values are appropriate (represent an actual suit or rank).
#
# More implementation details are included in the method comments in `card.py`.
#
# Write the `setSuit`, `getSuit`, `setRank`, and `getRank` functions.
#
# *Hint*: `assert` is a great way to check the properties of interest in the `set` methods!

# %% [markdown]
# #### Part 2
#
# Now we're ready to create the `__init__` method which will actually allow us to make cards! This method should take in a suit and rank and create a card object with those properties. It should additionally ensure that the suit and rank input values are valid before creating a card; it should throw an `AssertionError` if they aren't.
#
# More implementation details are included in the method comments in `card.py`.
#
# Write the `__init__` method.
#
# *Hint*: You'll make your life much easier if you use the method you wrote for Part 1!

# %% [markdown]
# #### Part 3
#
# We've written a lot of code without testing it...
#
# The import statement in the code block below allows you to access the `Card` object you've written in `card.py`. Using it, you can initialize `Card` objects in this notebook!
#
# Use this functionality to write tests which cover the following:
# - `__init__` creates a `Card` object whose attributes match those passed as arguments
# - `__init__` throws an `AssertionError` when given an invalid `rank` or `suit`
# - `getRank` correctly returns a `Card`s rank
# - `getSuit` correctly returns a `Card`s suit
# - `setRank` correct changes a `Card`'s rank
# - `setRank` throws an `AssertionError` when passed a non-integer
# - `setRank` throws an `AssertionError` when passed an integer that is *not* a valid rank
# - `setSuit` correct changes a `Card`'s suit
# - `setSuit` throws an `AssertionError` when passed a non-integer
# - `setSuit` throws an `AssertionError` when passed an integer that is *not* a valid suit
#
# *Hint*: It's possible to write tests which evaluate several of these criteria at the same time.
#
# *Hint*: To check whether an `AssertionError` is thrown, check out [this source](https://www.w3schools.com/python/python_try_except.asp) on Try and Except in Python.

# %%
from card import Card

c = Card(0, 3)

# %% [markdown]
# #### Part 4
#
# We may want to represent a `Card` in an easily human-readable way. The `__str__` method asks you to create different string representations of a card.
#
# More implementation details are included in the method comment in `card.py`.

# %% [markdown]
# #### Part 5
#
# Let's test `__str__`! Write 3-4 tests for the method in the code block below.

# %%
# Write your tests here

# %% [markdown]
# #### Part 6
#
# There are three remaining methods that make up the `Card` class: `__eq__`, `__lt__`, and `__gt__`. These methods compare `self` with another card and determine whether it is equal to, less than, or greater than that card in value. We'll use the poker ordering of cards, where ace is the highest and 2 the lowest.
#
# Ask the AI chatbot of your choice to write versions of all three methods. Make sure the functionality of the methods matches what is described in the method comments.
#
# Then, in few sentences, reflect on this process. In particular, compare the experience of getting a chatbot to write code that needs to integrate with an existing class with writing independent code.

# %% [markdown]
# ---
#
# *[Name your chatbot and paste all interactions here – prompts and responses]*
#
# ---

# %% [markdown]
# ---
#
# *[Write your analysis here]*
#
# ---

# %% [markdown]
# #### Part 7
#
# We usually want a whole deck of cards, not just one!
#
# Write a function, `full_deck`, which returns a list of all 52 cards in a standard deck.

# %%
def full_deck():
    pass # Write your code here
