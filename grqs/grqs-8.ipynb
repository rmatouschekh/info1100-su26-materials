# %% [markdown]
# ## GRQs: Recursion
# ***due Wednesday 07/08 at 11:30am (EST)***
#
# Answer each of the following questions with either the requested code or a multi-sentence written response. This assignment will be scored on completion.

# %% [markdown]
# ---
#
# **Name:** *[Your name here]*
# **ID:** *[Your netID here]*
#
# ---

# %% [markdown]
# ### Question 1
# *Adapted from Exercise 5.14.4 in "Think Python" by Allen B. Downey*
#
# Consider the following function:
# ```python
# def recurse(n, s):
#     if n == 0:
#         print(s)
#     else:
#         recurse(n-1, n+s)
# ```
#
#
# Draw a stack diagram that shows the state of the program when it prints the result of calling `recurse(3, 0)`. Attach a photo of your stack diagram to the submission of this assignment.
#
# Then, write a 1-2 sentence description of what this function does. Feel free to play around and call the function with a variety of values to see what happens!

# %% [markdown]
# ---
#
# *[Write your function description here]*
#
# ---

# %% [markdown]
# ### Question 2
# *Adapted from Exercise 5.14.1 in "Think Python" by Allen B. Downey*
#
# Below is an attempt at a recursive function that counts down by two.
#
# ```python
# def countdown_by_two(n):
#     if n == 0:
#         print('Blastoff!')
#     else:
#         print(n)
#         countdown_by_two(n-2)
# ```
#
# If we run `countdown_by_two(6)`, it seems to work. But it has an error!
#
# Ask the AI chatbot of your choice what's wrong with the function and how to fix it. Make sure you understand the solution.

# %% [markdown]
# ---
#
# *[Name your chatbot and paste all interactions here – prompts and responses]*
#
# ---

# %%
# Write the corrected function here

# %% [markdown]
# ### Question 3
# *Adapted from Exercise 6.12.5 in "Think Python" by Allen B. Downey*
#
# The greatest common divisor (GCD) of $a$ and $b$ is the largest number that divides both of them with no remainder.
#
# One way to find the GCD of two numbers is based on the observation that if $r$ is the remainder when $a$ is divided by $b$, then $gcd(a,b) = gcd(b,r)$. As a base case, we can use $gcd(a, 0) = a$.
#
# Write a function called `gcd` that takes parameters `a` and `b` and returns their greatest common divisor. Then, write 2-3 tests for the function (feel free to look up what the GCD is of your test values).

# %%
# Write your function here

# %%
# Write your tests here
