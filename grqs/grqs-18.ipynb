# %% [markdown]
# ## GRQs: Data Visualization (in Python)
# ***due Thursday 07/30 at 11:30am (EST)***
#
# Answer each of the following questions with either the requested code or a multi-sentence written response. This assignment will be scored on completion.

# %% [markdown]
# ---
#
# **Name:** *[Your name here]*
# **ID:** *[Your netID here]*
#
# ---

# %%
# Run me before continuing!
# !pip install matplotlib
# %matplotlib inline
# Out:
# ...
#   Using cached matplotlib-3.10.9-cp313-cp313-macosx_11_0_arm64.whl.metadata (52 kB)
# ...
#   Using cached contourpy-1.3.3-cp313-cp313-macosx_11_0_arm64.whl.metadata (5.5 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached fonttools-4.63.0-cp313-cp313-macosx_10_13_universal2.whl.metadata (118 kB)
# ...
#   Using cached kiwisolver-1.5.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (5.1 kB)
# ...
#   Using cached pillow-12.2.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (8.8 kB)
# ...
#   Using cached pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# ...
# Using cached matplotlib-3.10.9-cp313-cp313-macosx_11_0_arm64.whl (8.2 MB)
# Using cached contourpy-1.3.3-cp313-cp313-macosx_11_0_arm64.whl (274 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached fonttools-4.63.0-cp313-cp313-macosx_10_13_universal2.whl (2.9 MB)
# Using cached kiwisolver-1.5.0-cp313-cp313-macosx_11_0_arm64.whl (64 kB)
# Using cached pillow-12.2.0-cp313-cp313-macosx_11_0_arm64.whl (4.7 MB)
# ...

# %% [markdown]
# ### Question 1.1
#
# Once again, consider the visualization below. Based on what you've learned, write a critique of the visualization, including 2-3 things you think it does well and 2-3 things it could improve.

# %% [markdown]
# <div style="text-align: center;">
#     <img src="grqs-files/data-viz-2.png" alt="drawing" width="800"/>
# </div>

# %% [markdown]
# ---
#
# *[Write your analysis here]*
#
# ---

# %% [markdown]
# ### Question 1.2
#
# Let's evaluate how well AI chatbots perform visualization critique! Ask two different AI chatbots of your choice to critique the visualization above, giving 2-3 positives and 2-3 negatives. Then, reflect on each response based on what you've learned in the past couple of days. What aligns with what you know? What doesn't? Which parts of the chatbot critiques seem useful, and what do you need to follow up on to fully understand?

# %% [markdown]
# ---
#
# *[Paste the first chatbot's name and your interactions with it, including the critique, here]*
#
# ---

# %% [markdown]
# ---
#
# *[Reflect on the first chatbot's critique]*
#
# ---

# %% [markdown]
# ---
#
# *[Paste the second chatbot's name and your interactions with it, including the critique, here]*
#
# ---

# %% [markdown]
# ---
#
# *[Reflect on the second chatbot's critique]*
#
# ---

# %% [markdown]
# ### Question 2
#
# Consider the plot below. Your job is to try and get the AI chatbot of your choice to write code that used Matplotlib to replicate the figure as closely as possible ***without showing it the figure***. That is, use only your words to try and lead the chatbot.
#
# You don't need to exactly (or even closely) match the colors and can use random approximates for the bar values.

# %% [markdown]
# <div style="text-align: center;">
#     <img src="grqs-files/data-viz-3.png" alt="drawing" width="500"/>
# </div>

# %% [markdown]
# ---
#
# *[Paste all chatbot interactions here – prompts and responses]*
#
# ---

# %%
# Paste your final visualization code here

# %% [markdown]
# #### Question 3.1
#
# We looked at the Bellevue Almshouse dataset when learning about dataframes. As a refresher, I've loaded the dataframe and displayed the first ten rows of it below
#
# Say I'm interested in exploring the interaction between each individual's age, gender, and the date they were registered. Describe, in detail, how you would visualize that data. Take into consideration all of the visualization principles we've learned. Then, explain your visualization choices.

# %%
# Load and display Bellevue Almshouse dataset
import pandas as pd

bellevue_df = pd.read_csv("grqs-files/bellevue_almshouse_modified.csv")
bellevue_df.head(10)
# Out:
#       date_in first_name  last_name   age          disease profession gender  \
# 0  1847-04-17       Mary  Gallagher  28.0  recent emigrant    married      w
# 1  1847-04-08       John  Sanin (?)  19.0  recent emigrant    laborer      m
# 2  1847-04-17    Anthony      Clark  60.0  recent emigrant    laborer      m
# 3  1847-04-08   Lawrence     Feeney  32.0  recent emigrant    laborer      m
# 4  1847-04-13      Henry      Joyce  21.0  recent emigrant        NaN      m
# 5  1847-04-14    Bridget       Hart  20.0  recent emigrant   spinster      w
# 6  1847-04-14       Mary      Green  40.0  recent emigrant   spinster      w
# 7  1847-04-19     Daniel     Loftus  27.0      destitution    laborer      m
# 8  1847-04-10      James        Day  35.0  recent emigrant    laborer      m
# 9  1847-04-10   Margaret    Farrell  30.0  recent emigrant      widow      w
#
#                      children
# 0         Child Alana 10 days
# 1              Catherine 2 mo
# ...

# %% [markdown]
# ---
#
# *[Describe your visualization here]*
#
# ---

# %% [markdown]
# ---
#
# *[Explain your visualization choices here]*
#
# ---

# %% [markdown]
# ### Question 3.2
#
# AI chatbots are often quite talented at creating visualizations with Matplotlib. Take the visualization description you wrote above and use it to prompt the AI chatbot of your choice to write code that will create that visualization. Iterate until you can paste the code below and it will create the visualization you imagine – remember that the dataset is loaded as `bellevue_df` in the code above.
#
# Then, reflect on:
# - a) The process of creating this visualization with the chatbot. Was it easy? Did you have to iterate at all? Did you understand the code the model produced?
# - b) The effectiveness of your visualization. Now that you can see it, do you think it presents your data effectively? Why or why not? What changes would you make?

# %% [markdown]
# ---
#
# *[Paste all chatbot interactions here – prompts and responses]*
#
# ---

# %%
# Paste your visualization code here

# %% [markdown]
# ---
#
# *[Write your reflection on a) the process of creating the visualization here]*
#
# ---

# %% [markdown]
# ---
#
# *[Write your reflection on b) the visualization itself here]*
#
# ---
